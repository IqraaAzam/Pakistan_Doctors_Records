# %% [markdown]
# # 🩺 Pakistan Doctor Scraper using Selenium
#
# This script uses **Selenium** to scrape detailed information about doctors across **100+ cities** in Pakistan from **Google Maps**, aiming to collect **50,000+ records**.
#
# ---
#
# ## 🚀 Features
# - Covers major cities from all provinces: Punjab, Sindh, KP, Balochistan, AJK, and GB.
# - Searches for 40+ medical specializations (e.g., Cardiologists, Gynecologists, Pediatricians).
# - Automatically scrolls and navigates Google Maps results.
# - Stores data in `pakistan_doctors_50000.csv` with:
#   - **Doctor Name**
#   - **Specialization**
#   - **Hospital/Clinic**
#   - **City**
#   - **Rating**
#
# ---
#
# ## 🧰 Requirements
# ```bash
# pip install selenium webdriver-manager

# %%
import time
import csv
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# **🌍 More Cities for Better Coverage**
cities = [
    # Punjab
    "Lahore", "Faisalabad", "Rawalpindi", "Multan", "Gujranwala", "Sialkot", "Bahawalpur", "Sargodha",
    "Sahiwal", "Sheikhupura", "Jhang", "Rahim Yar Khan", "Okara", "Kasur", "Chiniot", "Gujrat", "Mandi Bahauddin",
    "Dera Ghazi Khan", "Vehari", "Hafizabad", "Attock", "Khanewal", "Bahawalnagar", "Muzaffargarh", "Narowal",
    "Jhelum", "Bhakkar", "Lodhran", "Pakpattan", "Toba Tek Singh", "Chakwal", "Khushab", "Mianwali", "Kamoke",
    "Pattoki", "Kot Addu", "Shujabad", "Fort Abbas", "Depalpur", "Kot Radha Kishan", "Kamalia", "Ahmedpur East",
    "Samundri", "Kabirwala", "Burewala",

    # Sindh
    "Karachi", "Hyderabad", "Sukkur", "Larkana", "Nawabshah", "Mirpur Khas", "Jacobabad", "Shikarpur", "Badin",
    "Khairpur", "Dadu", "Ghotki", "Umerkot", "Sanghar", "Tando Allahyar", "Tando Adam", "Tando Muhammad Khan",
    "Thatta", "Kashmore", "Kandhkot", "Matiari", "Hala", "Shahdadkot", "Sehwan", "Jamshoro", "Sujawal",
    "Kotri", "Tharparkar", "Mehar",

    # Khyber Pakhtunkhwa
    "Peshawar", "Mardan", "Mingora", "Abbottabad", "Kohat", "Dera Ismail Khan", "Swat", "Mansehra", "Charsadda",
    "Bannu", "Nowshera", "Swabi", "Hangu", "Tank", "Lakki Marwat", "Chitral", "Dir", "Battagram", "Shangla",
    "Haripur", "Toru", "Tangi",

    # Balochistan
    "Quetta", "Gwadar", "Turbat", "Chaman", "Khuzdar", "Hub", "Dera Murad Jamali", "Zhob", "Pishin", "Kalat",
    "Sibi", "Mastung", "Loralai", "Nushki", "Dalbandin", "Ziarat", "Kharan", "Qila Saifullah", "Qila Abdullah",

    # Azad Jammu and Kashmir (AJK)
    "Muzaffarabad", "Mirpur", "Kotli", "Bagh", "Rawalakot", "Poonch", "Neelum", "Haveli",

    # Gilgit-Baltistan
    "Gilgit", "Skardu", "Hunza", "Diamer", "Ghizer", "Ghanche", "Shigar", "Kharmang", "Nagar", "Astore"
]


# **🔍 Expanded Search Queries to Cover More Doctors**
search_queries = [
    "Best Doctors in ", "Top Hospitals in ", "Specialist Doctors in ", "Clinics in ",  
    "Medical Specialists in ", "General Physicians in ", "Surgeons in ", "Pediatricians in ",  
    "Gynecologists in ", "Dermatologists in ", "ENT Specialists in ", "Cardiologists in ",  
    "Neurologists in ", "Nephrologists in ", "Endocrinologists in ", "Gastroenterologists in ",  
    "Oncologists in ", "Hematologists in ", "Pulmonologists in ", "Hepatologists in ",  
    "Rheumatologists in ", "Orthopedic Surgeons in ", "Urologists in ", "Ophthalmologists in ",  
    "Psychiatrists in ", "Psychologists in ", "Allergists in ", "Immunologists in ",  
    "Infectious Disease Specialists in ", "Pain Management Specialists in ",  
    "Rehabilitation Specialists in ", "Plastic Surgeons in ", "Geriatricians in ",  
    "Sports Medicine Specialists in ", "Emergency Medicine Specialists in ",  
    "Sleep Medicine Specialists in ", "Palliative Care Specialists in ",  
    "Medical Geneticists in ", "Neonatologists in "
]

# **🚀 Chrome Options**
chrome_options = Options()
chrome_options.add_argument("--headless")  # **Run in Background**
chrome_options.add_argument("--disable-blink-features=AutomationControlled")
chrome_options.add_argument("--log-level=3")

service = Service(ChromeDriverManager().install())  # Automatically install ChromeDriver
driver = webdriver.Chrome(service=service, options=chrome_options)


# **📂 CSV File to Store Data**
filename = "pakistan_doctors_50000.csv"
with open(filename, "w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Doctor Name", "Specialization", "Hospital/Clinic", "City", "Rating"])

    total_records = 0
    target_records = 50000  # **Target 50,000+ Records**

    for city in cities:
        if total_records >= target_records:
            break  # **Stop once 50,000 records are reached**

        for query in search_queries:
            if total_records >= target_records:
                break
            
            print(f"\n🔍 Searching: {query} {city}")

            # **🔍 Open Google Maps & Search**
            driver.get("https://www.google.com/maps")
            time.sleep(3)

            search_box = driver.find_element(By.ID, "searchboxinput")
            search_box.clear()
            search_box.send_keys(query + city)
            search_box.send_keys(Keys.RETURN)
            time.sleep(5)

            city_records = 0
            max_records_per_city = 500  # **Increase Limit to 500 Per City**

            # **🔄 Scrolling Mechanism to Load More Results**
            for _ in range(10):  # **Scroll 10 times**
                driver.execute_script("document.querySelector('div[role=\"feed\"]').scrollBy(0, 1000);")
                time.sleep(2)

            retry_attempts = 3  # **Retry if no results**
            while city_records < max_records_per_city and total_records < target_records:
                results = driver.find_elements(By.CLASS_NAME, "Nv2PK")

                if not results and retry_attempts > 0:
                    print("⚠️ No results found, retrying...")
                    time.sleep(3)
                    retry_attempts -= 1
                    continue

                for result in results:
                    try:
                        name = result.find_element(By.CLASS_NAME, "qBF1Pd").text.strip()
                        if not name.startswith("Dr"):
                            continue  # **Ensure Only Doctor Listings**

                        address = result.find_element(By.CLASS_NAME, "W4Efsd").text.strip()
                        details = result.text.split("\n")

                        # **🔬 Extract Specialization**
                        specialization = "Unknown"
                        if len(details) > 1:
                            specialization = details[1]

                        # **🏥 Extract Hospital/Clinic Name**
                        hospital = "Not Available"
                        if "Clinic" in address or "Hospital" in address or "Medical Center" in address:
                            hospital = address
                        elif len(details) > 2:
                            hospital = details[2]

                        # **⭐ Extract Rating**
                        rating = "Not Available"
                        try:
                            rating = result.find_element(By.CLASS_NAME, "MW4etd").text.strip()
                        except:
                            pass  # **If No Rating, Skip**

                        # **📌 Save Data to CSV**
                        writer.writerow([name, specialization, hospital, city, rating])
                        print(f"✅ {name} - {specialization} - {hospital} - {city} - ⭐ {rating}")

                        city_records += 1
                        total_records += 1
                        if city_records >= max_records_per_city or total_records >= target_records:
                            break

                    except Exception as e:
                        print(f"❌ Error: {e}")
                        continue

                try:
                    # **➡️ Click Next Page for More Results**
                    next_button = driver.find_element(By.CSS_SELECTOR, '[aria-label="Next"]')
                    next_button.click()
                    time.sleep(5)
                except:
                    print(f"🔚 No more pages for {city}")
                    break

print(f"\n✅ Total {total_records} Records Successfully Saved!\n📂 File: {filename}")
driver.quit()
# Out:
# 🔍 Searching: Best Doctors in  Lahore
# ✅ Dr. Mujahid Israr | Best Gastroenterologist in Lahore - 4.7(75) - Gastroenterologist ·  · National Hospital & Medical Center, 132/2 Street 123 - Lahore - ⭐ 4.7
# ✅ Dr. Khurshid Alam | Best ENT Specialist Lahore - 4.2(96) - Otolaryngologist ·  · 152-G, Doctor's Hospital, 1 Canal Rd - Lahore - ⭐ 4.2
# ✅ Dr. Hafiz Abdul Momin | Expert Urologist in Lahore - Penile Implant & Kidney Stone Specialist | MBBS, FCPS (Urology) - 4.8(472) - Urologist · Clinx Pharmacy, Chugtai Medical Center, Near41-A Shalimar Link Road, opposite Sahlimar Hospital - Lahore - ⭐ 4.8
# ✅ Dr. Fahmina Ashfaq - Sugar, Medical & Blood Pressure Specialist Lady Doctor - 4.9(113) - Doctor ·  · Block, Omar hospital and cardiac centre, D2 - Lahore - ⭐ 4.9
# ✅ Dr. Samia Khan | Best General Physician in Lahore - 5.0(20) - General practitioner ·  · Chughtai Medical Center, 154 CAA - Lahore - ⭐ 5.0
# ✅ Dr. Maria Farooq | Gynecologist | Infertility Specialist |Laparoscopic Surgeon|cosmetic & aesthetic gynecologist - 4.9(370) - Obstetrician-gynecologist ·  · Salam Medical Complex, 320 Main Lahore – Kasur Rd, near Kalma Chowk Flyover - Lahore - ⭐ 4.9
# ✅ Dr.Sarah Javed (🥇Medical Specialist & consultant physician) - 5.0(130) - Doctor · Vital Care Hospital, 50A commercial lane - Lahore - ⭐ 5.0
# ✅ Dr. Muhammad Haseeb Nawaz | Best Gastroenterologist In Lahore | MBBS,MCPS (MEDICINE) ,FCPS (GASTRO) ,MACG, MASGE - 4.9(103) - Gastroenterologist · Salam Medical Complex, 320 Lahore – Kasur Rd - Lahore - ⭐ 4.9
# ✅ Dr. Abdul Rauf | Best Urologist in Lahore - 4.9(154) - Urologist ·  · F, Integrated Medical Care Hospital, Lahore, Phase-5 DHA - Entrance - Lahore - ⭐ 4.9
# ✅ Dr Usman Naeem's Liver and Endoscopy | Best Gastroenterologist Clinic in Lahore - 4.9(131) - Gastroenterologist · Aadil Hospital, D.H.A. Main Blvd - Lahore - ⭐ 4.9
# ✅ Dr. Furqan Saleem | Best Child Specialist |Trusted Pediatrician & Neonatologist in Lahore | MBBS,FCPS - 4.9(296) - Doctor ·  · Ammar medical complex, Jail Rd - Lahore - ⭐ 4.9
# ✅ Dr. Mujahid Israr | Best Gastroenterologist in Lahore - 4.9(151) - Gastroenterologist ·  · Omar Hospital & Cardiac Centre, Jail Rd - Lahore - ⭐ 4.9
# ✅ Dr. Mazhar ur Rehman - Heart & Lungs - Surgery Clinic - 4.9(245) - Surgeon ·  · 32-T، off MM Alam Rd - Lahore - ⭐ 4.9
# ✅ Dr. Muhammad Bilal, FCPS, FRCS | Best Orthopedic Lahore - 4.9(95) - Orthopedic surgeon ·  · Doctors Hospital 152 A - G, 1 Canal Rd - Lahore - ⭐ 4.9
# ✅ Dr Imad ud din Yousaf Butt Neurologist - Lahore, Pakistan - 4.9(663) - Neurologist ·  · Executive clinic Fatima Memorial Hospital - Lahore - ⭐ 4.9
# ✅ Dr. Somia Iqtadar - 4.9(29) - Internist ·  · 16 - Lahore - ⭐ 4.9
# ✅ Dr.Farhan ( General Physician) - 5.0(39) - Doctor · house # d/28, divine, gardens, near metro cash & carry - Lahore - ⭐ 5.0
# ✅ Dr Syed Muzahir Hussain- ENT Specialist Lahore - 4.8(147) - Otolaryngologist ·  · Room no 2 Ground Floor Niazi Hospital, Allah Hoo Chowk Rd - Lahore - ⭐ 4.8
# ✅ Dr.Zeeshan Ahmad Wains|best|Urologist In Lahore|top Andrologist |best penile implant surgeon,varicocelectomy.PCNL,URSI - 4.9(144) - Urologist ·  · Faisal, Khair-un-nisa Hospital, 17-C Block - Lahore - ⭐ 4.9
# ✅ Dr Huma Aslam Clinic - 4.9(157) - Psychiatrist · N - Lahore - ⭐ 4.9
# ✅ Dr. Muhammad Siddique Hamid | Spine Surgeon - South Korea - Best Orthopedic & Spine Surgeon in Lahore - 4.9(101) - Orthopedic surgeon ·  · Iqra Medical Complex (Ext)(New building - Lahore - ⭐ 4.9
# ✅ Dr Kash Clinic and Skin care - 4.8(99) - Skin care clinic ·  · House No.58, 21 - Lahore - ⭐ 4.8
# ✅ Dr. Zamurad Yasmin Rana Gynecologist - 4.9(68) - Gynecologist ·  · House # 4, Street # 7 Rajgarh Road Prem، street # 7 Rajgarh Rd - Lahore - ⭐ 4.9
# ✅ Dr Tariq Ahmed ( Best Gastroenterologist/ Liver Specalist)( Endoscopy/ Colonoscopy/ ERCP)معدہ جِگر لبلبہ اور انت اسپیشلسٹ - 4.9(148) - Gastroenterologist ·  · House No، 50-A Khayaban-e-Jamia Punjab - Lahore - ⭐ 4.9
# 🔚 No more pages for Lahore
#
# 🔍 Searching: Top Hospitals in  Lahore
# ✅ Dr Capt Arshad Humayun Hospital - 4.2(5) - Private hospital ·  · 21 Lahore road, bazar, near MCB, near sadar - Lahore - ⭐ 4.2
# 🔚 No more pages for Lahore
#
# 🔍 Searching: Specialist Doctors in  Lahore
# ✅ Dr. Khurshid Alam | Best ENT Specialist Lahore - 4.2(96) - Otolaryngologist ·  · 152-G, Doctor's Hospital, 1 Canal Rd - Lahore - ⭐ 4.2
# ✅ Dr. Mujahid Israr | Best Gastroenterologist in Lahore - 4.7(75) - Gastroenterologist ·  · National Hospital & Medical Center, 132/2 Street 123 - Lahore - ⭐ 4.7
# ✅ Dr. Fahmina Ashfaq - Sugar, Medical & Blood Pressure Specialist Lady Doctor - 4.9(113) - Doctor ·  · Block, Omar hospital and cardiac centre, D2 - Lahore - ⭐ 4.9
# ✅ Dr. Hafiz Abdul Momin | Expert Urologist in Lahore - Penile Implant & Kidney Stone Specialist | MBBS, FCPS (Urology) - 4.8(472) - Urologist · Clinx Pharmacy, Chugtai Medical Center, Near41-A Shalimar Link Road, opposite Sahlimar Hospital - Lahore - ⭐ 4.8
# ✅ Dr. Samia Khan | Best General Physician in Lahore - 5.0(20) - General practitioner ·  · Chughtai Medical Center, 154 CAA - Lahore - ⭐ 5.0
# ✅ Dr Hafiz Sohaib Fraz Ear Nose Face Neck Surgeon Shaikh Zayed Hospital Lahore - 4.8(203) - Medical clinic ·  · A, UHS street, Block - Lahore - ⭐ 4.8
# ✅ Dr Azhar Alam - 4.9(187) - Surgeon ·  · NOOR Hospital, Lahore – Kasur Rd, opposite Descon Headoffice - Lahore - ⭐ 4.9
# ✅ Dr. Nouman Hameed | M.B.B.S., F.C.P.S. (Gasto)| Best Gastroenterologist in Lahore | Endoscopy, Colonoscopy, ERCP Specialist - 4.9(67) - Gastroenterologist ·  · Iffat Anwar Medical Complex, near Wapda town - Lahore - ⭐ 4.9
# ✅ Dr. Muhammad Haseeb Nawaz | Best Gastroenterologist In Lahore | MBBS,MCPS (MEDICINE) ,FCPS (GASTRO) ,MACG, MASGE - 4.9(103) - Gastroenterologist · Salam Medical Complex, 320 Lahore – Kasur Rd - Lahore - ⭐ 4.9
# ✅ Dr Fahd Aziz Rana - 4.5(125) - Doctor ·  · Plot No. 393-396 & 423-426, Omar Hospital, Street 2 - Lahore - ⭐ 4.5
# ✅ Dr.Sarah Javed (🥇Medical Specialist & consultant physician) - 5.0(130) - Doctor · Vital Care Hospital, 50A commercial lane - Lahore - ⭐ 5.0
# ✅ Dr. Amin Mazhar Choudhary - 5.0(54) - Surgeon · 24, 25, Iqraa Medical Complex (Ext, 26 Maulana Shaukat Ali Rd - Lahore - ⭐ 5.0
# ✅ Dr. Mazhar ur Rehman - Heart & Lungs - Surgery Clinic - 4.9(245) - Surgeon ·  · 32-T، off MM Alam Rd - Lahore - ⭐ 4.9
# ✅ Dr Syed Muzahir Hussain- ENT Specialist Lahore - 4.8(147) - Otolaryngologist ·  · Room no 2 Ground Floor Niazi Hospital, Allah Hoo Chowk Rd - Lahore - ⭐ 4.8
# ✅ Dr Muhammad Rizwan Ali - Consultant Orthopaedic & Spine Surgeon...骨科医生 &脊柱外科医生,...استخوانپزشک,...جراح اختصاصي عظام - 5.0(166) - Orthopedic surgeon ·  · Doctors hospital and medical center 152 G1 - Lahore - ⭐ 5.0
# ✅ Dr. Muhammad Bilal, FCPS, FRCS | Best Orthopedic Lahore - 4.9(95) - Orthopedic surgeon ·  · Doctors Hospital 152 A - G, 1 Canal Rd - Lahore - ⭐ 4.9
# ✅ Dr. Abdul Rauf | Best Urologist in Lahore - 4.9(154) - Urologist ·  · F, Integrated Medical Care Hospital, Lahore, Phase-5 DHA - Entrance - Lahore - ⭐ 4.9
# ✅ Dr. Somia Iqtadar - 4.9(29) - Internist ·  · 16 - Lahore - ⭐ 4.9
# ✅ Dr. Maria Farooq | Gynecologist | Infertility Specialist |Laparoscopic Surgeon|cosmetic & aesthetic gynecologist - 4.9(370) - Obstetrician-gynecologist ·  · Salam Medical Complex, 320 Main Lahore – Kasur Rd, near Kalma Chowk Flyover - Lahore - ⭐ 4.9
# ✅ Dr. Mujahid Israr | Best Gastroenterologist in Lahore - 4.9(151) - Gastroenterologist ·  · Omar Hospital & Cardiac Centre, Jail Rd - Lahore - ⭐ 4.9
# ✅ Dr. Furqan Saleem | Best Child Specialist |Trusted Pediatrician & Neonatologist in Lahore | MBBS,FCPS - 4.9(296) - Doctor ·  · Ammar medical complex, Jail Rd - Lahore - ⭐ 4.9
# ✅ Dr Mursleen Clinic - 4.9(32) - Family practice physician ·  · Main street qadri colony street no 2, Walton Rd, near bhola chowk - Lahore - ⭐ 4.9
# 🔚 No more pages for Lahore
#
# 🔍 Searching: Clinics in  Lahore
# ✅ Dr Kash Clinic and Skin care - 4.8(99) - Skin care clinic ·  · House No.58, 21 - Lahore - ⭐ 4.8
# ✅ Dr. Jehangir Alam Clinic - 4.9(15) - Medical clinic · 2 Golf Road - Lahore - ⭐ 4.9
# ✅ Dr. Zarqa Clinic - Gulberg - 4.6(254) - Skin care clinic ·  · Syed Maratib Ali Road - Lahore - ⭐ 4.6
# ✅ Dr Mursleen Clinic - 4.9(32) - Family practice physician ·  · Main street qadri colony street no 2, Walton Rd, near bhola chowk - Lahore - ⭐ 4.9
# ✅ Dr Waris Anwar Aesthetics Clinic - 4.7(1,225) - Hair transplantation clinic · Plot 24 Block P - Lahore - ⭐ 4.7
# ✅ DrAamir's Specialist Homeopathic Online Clinic, Lahore - 4.0(20) - Medical clinic · Divine Mega 2, Ghazi Rd, behind Habib Bank Limited - Lahore - ⭐ 4.0
# ✅ Dr. Ahsan Mahmud Clinic - 4.9(10) - Specialized clinic ·  · 35-A, Off Main Boulevard Gulberg (Behind Mcdonalds - Lahore - ⭐ 4.9
# ✅ Dr. Farah’s Clinic - 3.4(48) - Dermatologist ·  · 42، A-Block, B-II Ghalib Rd - Lahore - ⭐ 3.4
# 🔚 No more pages for Lahore
#
# 🔍 Searching: Medical Specialists in  Lahore
# ✅ Dr. Fahmina Ashfaq - Sugar, Medical & Blood Pressure Specialist Lady Doctor - 4.9(113) - Doctor ·  · Block, Omar hospital and cardiac centre, D2 - Lahore - ⭐ 4.9
# ✅ Dr. Somia Iqtadar - 4.9(29) - Internist ·  · 16 - Lahore - ⭐ 4.9
# ✅ Dr.Sarah Javed (🥇Medical Specialist & consultant physician) - 5.0(130) - Doctor · Vital Care Hospital, 50A commercial lane - Lahore - ⭐ 5.0
# ✅ Dr. Samia Khan | Best General Physician in Lahore - 5.0(20) - General practitioner ·  · Chughtai Medical Center, 154 CAA - Lahore - ⭐ 5.0
# ✅ Dr.Farhan ( General Physician) - 5.0(39) - Doctor · house # d/28, divine, gardens, near metro cash & carry - Lahore - ⭐ 5.0
# ✅ Dr. Mujahid Israr | Best Gastroenterologist in Lahore - 4.7(75) - Gastroenterologist ·  · National Hospital & Medical Center, 132/2 Street 123 - Lahore - ⭐ 4.7
# ✅ Dr. Ammar Arshad (Consultant Physician,Medical Specialist,Gastroenterologist,Endoscopist),MBBS(KE),FCPS(Medicine),MRCP(UK) - 5.0(9) - Doctor · Fatima Memorial Hospital - Lahore - ⭐ 5.0
# ✅ Dr Mursleen Clinic - 4.9(32) - Family practice physician ·  · Main street qadri colony street no 2, Walton Rd, near bhola chowk - Lahore - ⭐ 4.9
# ✅ Dr Syed Sibtain Ul Hassan (Internal Medicine Specialist) Liver & Diabetes clinic - 5.0(114) - Hospital ·  · Ihsan mumtaz hospital, E BLOCK - Lahore - ⭐ 5.0
# ✅ Dr Muhammad Awais Abid Consultant Physician & Gastroenterologist - 4.8(211) - Doctor ·  · Midcity hospital jail road, 7.30 9.30 - Lahore - ⭐ 4.8
# ✅ Dr Ali Arsalan (Medical Specialist) - 5.0(1) - Doctor · Jail, Omar hospital and cardiac center, road - Lahore - ⭐ 5.0
# ✅ Dr Nauman Anjum Medical specialist & Diabetologist - 5.0(13) - Diabetologist ·  · 393-394 block D II johar town Johar - Lahore - ⭐ 5.0
# ✅ Dr. Arslan Shamim best diabetes stomach and liver specialist - 4.9(48) - Doctor · G8MV+X55 Ammar Medical Complex:, Jail Rd, Gulberg V, Lahore, Punjab 54000 Private - Lahore - ⭐ 4.9
# ✅ Dr Amanullah Clinic - 4.9(21) - Medical Center ·  · Islamabad Diagnostic Centre (IDC, Main Jail Rd, near KFC - Lahore - ⭐ 4.9
# ✅ Dr. Mehrin Farooq - 5.0(7) - Internist · Dr. Mehrin Farooq Chughtai Medical Center 194-CCA - Lahore - ⭐ 5.0
# ✅ Dr. Mujahid Israr | Best Gastroenterologist in Lahore - 4.9(151) - Gastroenterologist ·  · Omar Hospital & Cardiac Centre, Jail Rd - Lahore - ⭐ 4.9
# ✅ Dr.Imran Clinic (Home Checkup/Online Consultation) - 4.7(13) - Family practice physician ·  · B, Mian Chok Jubilee Town, Road - Lahore - ⭐ 4.7
# 🔚 No more pages for Lahore
#
# 🔍 Searching: General Physicians in  Lahore
# ✅ Dr. Samia Khan | Best General Physician in Lahore - 5.0(20) - General practitioner ·  · Chughtai Medical Center, 154 CAA - Lahore - ⭐ 5.0
# ✅ Dr.Farhan ( General Physician) - 5.0(39) - Doctor · house # d/28, divine, gardens, near metro cash & carry - Lahore - ⭐ 5.0
# 🔚 No more pages for Lahore
#
# 🔍 Searching: Surgeons in  Lahore
# ✅ Dr Amjad Saeed Mian - 4.9(284) - Surgeon · Saleem Memorial Hospital - Lahore - ⭐ 4.9
# ✅ Dr Azhar Alam - 4.9(187) - Surgeon ·  · NOOR Hospital, Lahore – Kasur Rd, opposite Descon Headoffice - Lahore - ⭐ 4.9
# ✅ Dr Abdul Basit Qureshi - Best Hernia & Gallbladder Surgeon - 5.0(38) - Surgeon ·  · unicare Medical center, 729 Shadman Rd, opposite FMH Lahore - Lahore - ⭐ 5.0
# ✅ Dr Syed Mohsin Azeem - 5.0(67) - Surgeon · 5 Jail Rd - Lahore - ⭐ 5.0
# ✅ Dr. Amin Mazhar Choudhary - 5.0(54) - Surgeon · 24, 25, Iqraa Medical Complex (Ext, 26 Maulana Shaukat Ali Rd - Lahore - ⭐ 5.0
# ✅ Dr Waqas Ur Rehman (Pediatric Surgeon) | Best Pediatric Surgeon in Lahore & Sialkot - 5.0(60) - Pediatric surgeon · II, Plot No. 393-396 & 423-426 Street 2 Block D - Lahore - ⭐ 5.0
# ✅ Dr. Muhammad Siddique Hamid | Spine Surgeon - South Korea - Best Orthopedic & Spine Surgeon in Lahore - 4.9(101) - Orthopedic surgeon ·  · Iqra Medical Complex (Ext)(New building - Lahore - ⭐ 4.9
# ✅ Dr MS Khan Surgery Clinic - 4.9(26) - Surgeon · First Floor, Hameed Latif Medical Center, CCA 20 - Lahore - ⭐ 4.9
# ✅ Dr. Amin Yousaf Plastic Surgeon - 4.7(208) - Plastic surgeon · 35-H3 Expo Center Rd - Lahore - ⭐ 4.7
# ✅ Dr Salman Majeed Chaudhry - 5.0(20) - Surgeon ·  · Zafar Ali Rd - Lahore - ⭐ 5.0
# ✅ Dr Junaid Ahmad Plastic Surgery - 4.8(84) - Hospital ·  · Allah Hoo Chowk - Lahore - ⭐ 4.8
# ✅ Dr Muhammad Rizwan Ali - Consultant Orthopaedic & Spine Surgeon...骨科医生 &脊柱外科医生,...استخوانپزشک,...جراح اختصاصي عظام - 5.0(166) - Orthopedic surgeon ·  · Doctors hospital and medical center 152 G1 - Lahore - ⭐ 5.0
# ✅ Dr. Atta-ul-Haq Plastic Surgeon - 4.9(64) - Plastic surgeon ·  · 35-H3 Expo Center Rd - Lahore - ⭐ 4.9
# ✅ Dr. Sheraz Raza | Best Rhinoplasty Surgeon in Lahore | Facelift | Breast lift | Liposuction | Mummy Make Over - 4.7(306) - Surgeon ·  · 153/1 - Lahore - ⭐ 4.7
# ✅ Dr. Somer Masood (Surgical Oncologist, Breast Oncoplastic Surgeon, Reconstructive Surgeon, Advanced Laparoscopic Surgeon) - 4.9(47) - Surgeon ·  · Mid City Hospital, Main Jail Rd - Lahore - ⭐ 4.9
# ✅ Dr. Kamran Zaib - 5.0(14) - Surgeon ·  · Building # 462, 463 Khokhar Chowk - Lahore - ⭐ 5.0
# ✅ Dr. Muhammad Bilal, FCPS, FRCS | Best Orthopedic Lahore - 4.9(95) - Orthopedic surgeon ·  · Doctors Hospital 152 A - G, 1 Canal Rd - Lahore - ⭐ 4.9
# ✅ Dr Salman Hameed - 4.9(16) - Plastic surgeon · Ferozpur Rd, Service Road - Lahore - ⭐ 4.9
# ✅ Dr. Bushra Akram | Plastic Surgeon - 5.0(26) - Surgeon ·  · Lahore Care Hospital, Near Ghazi Road, Main Doctors Onboard, 35 Lahore – Kasur Rd - Lahore - ⭐ 5.0
# ✅ Dr Fahad Nazir MBBS,FACS(USA),FCPS(Orth), MRCS(Edin),MRCS(Glasg) Orthopedic Surgeon, Spine Surgeon, Arthroscopy, Trauma, Joint Replacements - 4.8(117) - Orthopedic surgeon ·  - Lahore - ⭐ 4.8
# ✅ Dr Muhammad Omar Afzal | Best Plastic Surgeon Lahore - 5.0(15) - Plastic surgeon ·  · Horizon Hospital - Lahore - ⭐ 5.0
# ✅ Dr. Khizer Ghalib | Best Spine Surgeon Lahore - 4.8(39) - Orthopedic surgeon ·  · Masood Hospital, 99 - Lahore - ⭐ 4.8
# ✅ Dr. Syed Baqir Jafree - The Best Orthopedic Surgeon in Lahore - 5.0(47) - Orthopedic surgeon · clinic corner, 28-A - Lahore - ⭐ 5.0
# ✅ Dr. Mazhar ur Rehman - Heart & Lungs - Surgery Clinic - 4.9(245) - Surgeon ·  · 32-T، off MM Alam Rd - Lahore - ⭐ 4.9
# 🔚 No more pages for Lahore
#
# 🔍 Searching: Pediatricians in  Lahore
# ✅ Dr. Sajida Zaman Child Specialist - 4.6(54) - Pediatrician ·  · 64/13 Sarfaraz Rafiqui Rd - Lahore - ⭐ 4.6
# ✅ Dr. Furqan Saleem | Best Child Specialist |Trusted Pediatrician & Neonatologist in Lahore | MBBS,FCPS - 4.9(296) - Pediatrician ·  · Ammar medical complex, Jail Rd - Lahore - ⭐ 4.9
# ✅ Dr. Muhammad Zeeshan Khan, MBBS, FCPS, Child Specialist - 4.9(120) - Pediatrician ·  · 7, near Khokhar Chowk - Lahore - ⭐ 4.9
# ✅ Dr Rizwan Gohar -l- Child Specialist -l- Best Pediatrician -l- MBBS -l- FCPS Vaccination centre for children & kids - 4.9(470) - Pediatrician ·  · Building # 462, 463, Khokhar Chowk - Lahore - ⭐ 4.9
# ✅ Dr.Shahzad Khurram (Child specialist/Paediatrician DHA lahore) - 4.9(76) - Pediatrician ·  · AMT 430- EE, phase 4, DHA, 4 Ghazi Rd - Lahore - ⭐ 4.9
# ✅ Dr Waqas Ur Rehman (Pediatric Surgeon) | Best Pediatric Surgeon in Lahore & Sialkot - 5.0(60) - Pediatric surgeon · II, Plot No. 393-396 & 423-426 Street 2 Block D - Lahore - ⭐ 5.0
# ✅ Dr. Ghazala Hafeez Butt Child Specialist Lahore - 5.0(16) - Pediatrician · 7, near Khokhar Chowk - Lahore - ⭐ 5.0
# ✅ Dr.Hammad Hassan Child Specialist Nusrat Hospital Lake City interchange Road Eden Lane villas - 4.9(35) - Medical clinic · 13 Ring Road, near Lake City Interchange - Lahore - ⭐ 4.9
# ✅ Dr. GM Chaudhary (Pediatric Surgeon & Pediatric Urologist) | Best Pediatric Surgeon in Lahore - 5.0(144) - Pediatric surgeon ·  · Iffat Anwar Medical Complex, Sutlej Ave,PGECHS, near Awaisia Housing Society Park, Awasia Housing Society Awaisia Housing Scheme, Johar - Lahore - ⭐ 5.0
# ✅ Dr Saad Farooq 🎖️Best Child Specialist/Pediatrician 🏥 Health care center for children & kids 🎓 MBBS, FCPS - 5.0(10) - Pediatrician · 50-A Commercial Khayaban e Amin - Lahore - ⭐ 5.0
# ✅ Dr. Binish Ali (Child Specialist) - Best Pediatrician - MBBS - FCPS (Paeds) - PGPN (USA) - 4.5(19) - Pediatrician ·  · Iqraa Medical Complex, 5 - A Maulana Shaukat Ali Rd - Lahore - ⭐ 4.5
# ✅ Dr. M. Zeeshan Khan Child Specialist - 5.0(18) - Pediatrician ·  · House 72 - Lahore - ⭐ 5.0
# ✅ Dr. Wafa-e-Aisha - 5.0(6) - Pediatrician · GC35+482 - Lahore - ⭐ 5.0
# ✅ Dr Saleem Niazi Pediatric & Neonatal Surgeon - 4.7(180) - Pediatric surgeon · 402 Haider Rd - Lahore - ⭐ 4.7
# ✅ Dr Naveed Haider Pediatric Surgeon (Children Surgeon) - 5.0(43) - Pediatric surgeon · Niazi Hospital Allah hoo chowk - Lahore - ⭐ 5.0
# ✅ Dr A Rehman Sher Child Specialist - 5.0(13) - Pediatrician · E-73, Main Double Road, Bedian Rd - Lahore - ⭐ 5.0
# ✅ Dr Bilal Zafar (child specialist) — Best pediatrician - 4.7(25) - Pediatrician · 155C1 Nespak society Phase 1 near Ghazi chowk township lahore Nespak phase, 1 - Lahore - ⭐ 4.7
# ✅ Dr. Ali Arshad, Assistant Professor Pediatrics, Child Specialist - 4.8(58) - Pediatrician · House no. 11-A, opposite Doctors - Lahore - ⭐ 4.8
# ✅ Dr. Armaghan Ahmed (Pediatric Surgeon) - 5.0(23) - Pediatric surgeon · 152-G, Doctors Hospital & Medical Center, 1 Canal Rd - Lahore - ⭐ 5.0
# ✅ Dr Asif Chaudhary. MBBS, MRCPCH, London.FRCPCH, UK. Consultant Child Specialist. - 5.0(55) - Children Policlinic · U.E.T. Housing Society, 147 B - Lahore - ⭐ 5.0
# ✅ Dr. Tariq Rafiq Khan - 4.7(25) - Doctor ·  · House No, 3-A Usmani Rd - Lahore - ⭐ 4.7
# ✅ Dr Muhammad Kashif Child Specialist | Children's Clinic - 5.0(14) - Pediatrician · 241/A Main Boulevard, near Punjab College/UCP - Lahore - ⭐ 5.0
# ✅ Dr. Sajjad Rafique - Pediatrician - 4.3(20) - Pediatrician · 35 - F - Lahore - ⭐ 4.3
# ✅ Dr. Abdul Qadir - Child Specialist - 5.0(15) - Pediatrician - Lahore - ⭐ 5.0
# ✅ Dr Arshad Pervaiz (child specialist) - 4.5(96) - Doctor · 43-A Sultan Ahmed Rd - Lahore - ⭐ 4.5
# ✅ Dr. Muhammad Naseem Javed - 4.9(21) - Pediatric urologist - Lahore - ⭐ 4.9
# ✅ Dr Naeem Zafar Child Specialist - 4.7(24) - Medical clinic · 9G Mushtaq Ahmed Gurmani Rd - Lahore - ⭐ 4.7
# ✅ Dr. SHOAIB BUTT - 4.5(62) - Children Policlinic · Street 8 Street 8 - Lahore - ⭐ 4.5
# ✅ Dr.Ammara Furqan-Developmental Pediatrician - 4.9(16) - Pediatric clinic · 80-E1 Wapda - Lahore - ⭐ 4.9
# ✅ Dr Aqsa Hasham | Pediatric Clinic - Healthcare Just for Kids - 5.0(12) - Pediatrician · House # 15-B, Main Canal Bank Rd, opposite Sukh Chayn Gradens, near Shahkam Chowk - Lahore - ⭐ 5.0
# ✅ Dr Saeed - 4.1(9) - Pediatrician · G9Q2+69Q - Lahore - ⭐ 4.1
# ✅ Dr Khalid Ilyas Children Clinic - 4.5(52) - Doctor · H97P+Q96, Ganj Bazar Road - Lahore - ⭐ 4.5
# ✅ Dr Amir Naseer Qureshi Child Specialist - 5.0(4) - Pediatrician · G82H+MVV - Lahore - ⭐ 5.0
# ✅ Dr Khurram Lone- Child Specialist - 5.0(3) - Pediatrician · Omar hospital, Plot 435 - Lahore - ⭐ 5.0
# 🔚 No more pages for Lahore
#
# 🔍 Searching: Gynecologists in  Lahore
# ✅ Dr. Samina Siddique | Best Gynecologist in Lahore (MBBS, FCPS) - 4.7(261) - Gynecologist ·  · Hameed Latif Medical Center, CCA, Street 20 - Lahore - ⭐ 4.7
# ✅ Dr. Maria Farooq | Gynecologist | Infertility Specialist |Laparoscopic Surgeon|cosmetic & aesthetic gynecologist - 4.9(370) - Obstetrician-gynecologist ·  · Salam Medical Complex, 320 Main Lahore – Kasur Rd, near Kalma Chowk Flyover - Lahore - ⭐ 4.9
# ✅ Dr. Samar Hussain - Best Gynecologist in Lahore - 5.0(60) - Gynecologist · Plot No. 394, Omar Hospital and Cardiac Center - Lahore - ⭐ 5.0
# ✅ Dr Mudassara Rafi | Best Gynecologist in Lahore - 5.0(24) - Gynecologist · OMC 15, Jail Rd, opposite Kinnaird College - Lahore - ⭐ 5.0
# ✅ Dr. Kiran Usman - Best Gynecologist & Top Infertility Specialist - 5.0(145) - Obstetrician-gynecologist · Evercare Hospital - Lahore - ⭐ 5.0
# ✅ Dr Sumbal Afzal - Gynaecologist - 4.8(149) - Gynecologist · E 16, 2 Walton Rd - Lahore - ⭐ 4.8
# ✅ Dr. Zamurad Yasmin Rana Gynecologist - 4.9(68) - Gynecologist ·  · House # 4, Street # 7 Rajgarh Road Prem، street # 7 Rajgarh Rd - Lahore - ⭐ 4.9
# ✅ Dr Saira Riaz - Best Gynecologist & Obstetrician - 5.0(165) - Gynecologist · 729 - Lahore - ⭐ 5.0
# ✅ Dr Rabia Mehmood Lahore (Gynecologist) - 4.9(37) - Obstetrician-gynecologist ·  · Ramay Clinic, Bedian Rd, near Gourmet Bakery, beside Royal Palace Marriage Hall - Lahore - ⭐ 4.9
# ✅ Dr. Ammara Naveed - 4.8(16) - Obstetrician-gynecologist · 174-C - Lahore - ⭐ 4.8
# ✅ Dr. Rabia Nosheen - 4.9(136) - Gynecologist · PHASE 12, 439 J Block Commercial DHA, EME - Lahore - ⭐ 4.9
# ✅ Dr. Samina Rasheed (MBBS, MCPS, FCPS) – Leading Gynaecologist in DHA Lahore - 5.0(22) - Obstetrician-gynecologist · Hameed Latif Medical Center, CCA St 10 - Lahore - ⭐ 5.0
# ✅ Dr Tanzeela Rehman - Gynecologist - 4.9(116) - Gynecologist · Omar Hospital and Cardiac center, 393 ll - Lahore - ⭐ 4.9
# ✅ Dr Rabia Mehmood - 5.0(26) - Obstetrician-gynecologist · D.H.A. Main Blvd - Lahore - ⭐ 5.0
# ✅ Dr Saima Zaki Gynecologist - 4.5(43) - Gynecologist ·  · Iqra Hospital Extension, Johar - Lahore - ⭐ 4.5
# ✅ Dr. Maria Farrukh Gynaecologist™ MBBS(KEMU), FCPS (Obs&Gynae) - 4.9(70) - Obstetrician-gynecologist · Airline Blvd - Lahore - ⭐ 4.9
# ✅ Dr Rukhsana Manzoor Zafar, Best Gynaecologist, Infertility specialist, Laparoscopic Surgeon - 5.0(14) - Obstetrician-gynecologist ·  · Sharif Medical City Hospital - Lahore - ⭐ 5.0
# ✅ Dr Sheema Babar Gynaecologist Clinic MRCOG FCPS Mrcpi - 4.9(303) - Doctor · 46G block - Lahore - ⭐ 4.9
# ✅ Dr. Khola Zeeshan | Best Gynecologist & Obstetrician | Lahore - 5.0(11) - Obstetrician-gynecologist ·  · F75G+3CX - Lahore - ⭐ 5.0
# ✅ Dr.Hifza Waqar | Female gynecologist | Obstetrics and Gynecology Consultant | Best gynecologist in Lahore - 4.4(7) - Obstetrician-gynecologist · G7QJ+X9J - Lahore - ⭐ 4.4
# ✅ Dr Rubab Ali | Best Gynecologist in Lahore - 5.0(102) - Obstetrician-gynecologist · 290 MB H DHA Phase 6 - Lahore - ⭐ 5.0
# 🔚 No more pages for Lahore
#
# 🔍 Searching: Dermatologists in  Lahore
# ✅ Dr. Sana Younas Dermatologist - 4.4(68) - Dermatologist ·  · Surgimed Hospital New Out Door 1, Zafar Ali Rd - Lahore - ⭐ 4.4
# ✅ Dr Umer Mushtaq - 4.1(95) - Dermatologist ·  · 154 CCA - Lahore - ⭐ 4.1
# ✅ Dr Huma Saleem - 4.9(135) - Dermatologist · Hameed Latif Medical centre - Lahore - ⭐ 4.9
# ✅ Dr Kanwal Jawad (DKJ AESTHETICS) - 4.9(162) - Dermatologist · DKJ Aesthetics 173 Main Boulevard. 1st Floor Commercial,Phase -6 DHA lahore Lahore, Punjab 54660 Lahore` - Lahore - ⭐ 4.9
# ✅ Dr. Maria Umer Skin & Laser Centre | Best Dermatologist & Skin Specialist in Lahore - 4.7(29) - Dermatologist · 70 - Lahore - ⭐ 4.7
# ✅ Dr Kash Clinic and Skin care - 4.8(99) - Skin care clinic ·  · House No.58, 21 - Lahore - ⭐ 4.8
# ✅ Dr Zafar ullah Khan ZUK SKINTHETICS - 4.8(136) - Dermatologist · 2 Shahrah Aiwan-e-Sanat-o-Tijarat - Lahore - ⭐ 4.8
# ✅ Dr. Zarqa Clinic - 4.8(188) - Dermatologist · DHA 195 - Lahore - ⭐ 4.8
# ✅ Dr. Rabia Hayat | Dermatologist in Lahore - 4.2(17) - Dermatologist ·  · 7 - Lahore - ⭐ 4.2
# ✅ Dr Samina Arshad Dermatologist - 5.0(12) - Dermatologist · Plot#3 , Block F-1,Phase 1 - Lahore - ⭐ 5.0
# ✅ Dr Azam Bukhari - 4.3(39) - Dermatologist · F8H2+2PH, Ghaus-e-Azam Rd - Lahore - ⭐ 4.3
# ✅ Dr Amina's Skin Clinic - 4.9(53) - Dermatologist ·  · 1st Floor, Emporium 2 PAF Falcon Complex Gulberg 3 - Lahore - ⭐ 4.9
# ✅ Dr. Humaira Shamim ( Skin Consultant, Acne Scar, Warts, Skin Tags, Pigmentation Removal, Chemical Peel, Electrocautery ) - 5.0(133) - Dermatologist ·  · 155-CCA, Defence Medical Group, (DD Commercial Zone - Lahore - ⭐ 5.0
# ✅ Dr Ch Muhammad Tahir Skin & LASER CENTER - 4.4(93) - Dermatologist · House No, WAPDA, 324 Street 4 - Lahore - ⭐ 4.4
# ✅ Dr. Zarqa Clinic - Gulberg - 4.6(254) - Dermatologist ·  · Syed Maratib Ali Road - Lahore - ⭐ 4.6
# ✅ Dr Nadia's Skin Confidence Clinic - 4.6(53) - Dermatologist ·  · 68 D - Lahore - ⭐ 4.6
# ✅ Dr. M. Khawar Nazir - Dermatologist, Cosmetic, LASER & Hair Transplant Surgeon - 4.4(48) - Dermatologist ·  · Boston Aesthetics،، 15-A Hali Rd - Lahore - ⭐ 4.4
# ✅ Dr. Awais Dermatology - 4.9(11) - Dermatologist · 137 - Lahore - ⭐ 4.9
# ✅ Dr. Hamdah Aftab - 5.0(15) - Dermatologist · 27K Sir Syed Rd - Lahore - ⭐ 5.0
# ✅ Dr. Ali Hasnain Kazmi Skin clinic - 3.4(185) - Skin care clinic · 130-A - Lahore - ⭐ 3.4
# ✅ Dr Aly Feroze - 4.5(46) - Skin care clinic ·  · Plot 81, New - Lahore - ⭐ 4.5
# ✅ Dr. Farah’s Clinic - 3.4(48) - Dermatologist ·  · 42، A-Block, B-II Ghalib Rd - Lahore - ⭐ 3.4
# ✅ Dr Saamira Farid - 5.0(13) - Dermatologist · CSI , 158 A, Shah Jamal Rd - Lahore - ⭐ 5.0
# ✅ Dr.Sadaf Naveed Khan - 5.0(17) - Dermatologist - Lahore - ⭐ 5.0
# ✅ Dr. Muneeza Qamar/Optoderma - 4.7(12) - Dermatologist · Wapda town phase 1 block E1 211 - Lahore - ⭐ 4.7
# 🔚 No more pages for Lahore
#
# 🔍 Searching: ENT Specialists in  Lahore
# ✅ Dr. Khurshid Alam | Best ENT Specialist Lahore - 4.2(96) - Otolaryngologist ·  · 152-G, Doctor's Hospital, 1 Canal Rd - Lahore - ⭐ 4.2
# ✅ Dr Syed Muzahir Hussain- ENT Specialist Lahore - 4.8(147) - Otolaryngologist ·  · Room no 2 Ground Floor Niazi Hospital, Allah Hoo Chowk Rd - Lahore - ⭐ 4.8
# ✅ Dr Hafiz Sohaib Fraz Ear Nose Face Neck Surgeon Shaikh Zayed Hospital Lahore - 4.8(203) - Medical clinic ·  · A, UHS street, Block - Lahore - ⭐ 4.8
# ✅ Dr. Eiman Zahid | ENT Specialist and Surgeon | Pediatric & Adult | Children Hospital Lahore - 4.7(83) - Otolaryngologist ·  · 320 Lahore – Kasur Rd - Lahore - ⭐ 4.7
# ✅ Dr. Sarfraz Latif | ENT Specialist - 4.9(63) - Otolaryngologist · 1 Phase, Doctor’s Hospital And Medical Centr - Lahore - ⭐ 4.9
# ✅ Dr Abdul Shakoor Best ENT Specialist - 4.9(53) - Doctor · Zafar Hospital Main Barki, Road - Lahore - ⭐ 4.9
# ✅ Dr Hafiz Sohaib Fraz ENT Surgeon Shaikh Zayed Hospital Lahore - 5.0(1) - Otolaryngologist ·  · H8P4+GJF, Ahmed Ali Rd - Lahore - ⭐ 5.0
# ✅ Dr.Tahir Rashid, ENT Specialist. - 4.7(89) - Otolaryngologist ·  · KFC and ittefaq hospital, 107-Q road - Lahore - ⭐ 4.7
# ✅ Dr. Sajjad Akram ENT Surgeon (ENT Clinic) - 4.2(62) - Medical clinic · Butt Chowk، College Road - Lahore - ⭐ 4.2
# ✅ Dr Hafiz Sohaib Fraz ENT Surgeon - 4.4(14) - Medical clinic · H863+P4G - Lahore - ⭐ 4.4
# ✅ Dr Hafiz Sohaib Fraz ENT Surgeon Shaikh Zayed Hospital Lahore - 4.2(5) - Doctor · Plot 7 - Lahore - ⭐ 4.2
# ✅ Dr.Rumana Yasin ENT Specialist - 5.0(34) - Doctor · Block, AMT Medical & Dental Center, 430-EE Ghazi Rd, opposite to Attock Petroleum, near Hope Up Lift Foundation School - Lahore - ⭐ 5.0
# ✅ Dr. Mujeeb's ENT Clinic - 4.3(78) - Otolaryngologist ·  · 37 - Lahore - ⭐ 4.3
# ✅ Dr. Kashif Iqbal Malik - 4.4(14) - Otolaryngologist ·  · cakes and bakes, H#9 BlockE-2 Main boulevard opposite - Lahore - ⭐ 4.4
# ✅ Dr Hafiz Sohaib Fraz Ear Nose Face Neck Physician & Surgeon Shaikh Zayed Hospital Lahore - 5.0(2) - Otolaryngologist · HCQH+WC6 - Lahore - ⭐ 5.0
# ✅ Dr Abuzar Siddique ENT Specialist - 5.0(11) - Hospital · Guldasht town, Zarrar Shaheed Rd - Lahore - ⭐ 5.0
# ✅ Dr Naveed Aslam ENT - 4.2(31) - Medical Center ·  · G8JW+7V6 - Lahore - ⭐ 4.2
# ✅ Dr. Sarfraz Latif (ENT Surgeon) - 4.5(20) - Hospital ·  · G855+H3J - Lahore - ⭐ 4.5
# ✅ Dr. Kashif Iqbal Malik ENT Surgeon - 3.6(68) - Medical clinic ·  · C7PC+Q37 - Lahore - ⭐ 3.6
# ✅ Dr ALI RAZA s ENT Clinic - 4.3(40) - Consultant · Room No.1, Underneath, Ground Floor OPD 1, Healthcare.ORG, 3:30 to 5:30 PM, Shahkam Flyover, near Bahria Town - Lahore - ⭐ 4.3
# ✅ Dr Hafiz Sohaib Fraz ENT Surgeon Shaikh Zayed Hospital Lahore - No reviews - Doctor ·  · F8MC+6G6 - Lahore - ⭐ Not Available
# ✅ Dr. Shiraz Aslam - 3.3(11) - Otolaryngologist · Doctors Hospital, Johar town - Lahore - ⭐ 3.3
# 🔚 No more pages for Lahore
#
# 🔍 Searching: Cardiologists in  Lahore
# ✅ Dr. Muhammad Fayyaz Zafar MBBS, FCPS, Cardiologist in Lahore - 5.0(24) - Cardiologist ·  · 7 - Lahore - ⭐ 5.0
# ✅ Dr Ahmad Usman - Heart Specialist | Best Cardiologist in Lahore - 4.9(89) - Cardiologist ·  · Street 6 Sector - Lahore - ⭐ 4.9
# ✅ Dr Nouman Kazmi Cardiology Clinic - 5.0(66) - Heart hospital ·  · Zarrar Shaheed Rd - Lahore - ⭐ 5.0
# ✅ Dr. Muhammad Fayyaz Zafar, Cardiologist in Lahore - 5.0(2) - Cardiologist · 263، 262, Thokar Niaz baig, Main Canal Rd - Lahore - ⭐ 5.0
# ✅ Dr. Mazhar ur Rehman - Heart & Lungs - Surgery Clinic - 4.9(245) - Cardiologist ·  · 32-T، off MM Alam Rd - Lahore - ⭐ 4.9
# ✅ Dr Amanullah Clinic - 4.9(21) - Cardiologist ·  · Islamabad Diagnostic Centre (IDC, Main Jail Rd, near KFC - Lahore - ⭐ 4.9
# ✅ Dr Shahzad Majeed Bhatti - 5.0(3) - Cardiologist ·  · Zafar Ali Rd - Lahore - ⭐ 5.0
# ✅ Dr. M. Nabeel Akbar Chaudhry - 4.9(16) - Cardiologist ·  · Cardiomed Clinic, 16 - Lahore - ⭐ 4.9
# ✅ Dr Umer Cardiologist - 5.0(21) - Cardiologist ·  · IDC, Jail Rd, opp. Kinnaird college - Lahore - ⭐ 5.0
# ✅ Dr. Fraz Ahmad - Consultant & Interventional Cardiologist - 5.0(8) - Cardiologist · F, 153/1-Street # 6, Sector-F - Lahore - ⭐ 5.0
# ✅ Dr Ahmad Raza Butt / Cardiologist - 5.0(7) - Cardiologist · Hameed Latif Hospital - Lahore - ⭐ 5.0
# ✅ Dr. Aqib Javaid MBBS, FCPS Cardiology - 5.0(6) - Cardiologist - Lahore - ⭐ 5.0
# ✅ Dr Sajjad Hussain - 5.0(15) - Cardiologist · 25-Empress road Nova medical centre opposite Qilla gujjar singh police line - Lahore - ⭐ 5.0
# ✅ Dr. Ayman Nasieb | Heart Surgeon - Cardiothoracic & Vascular surgeon in Lahore - 4.5(11) - Cardiologist ·  · Plot No. 393-396 & 423-426, Omar Hospital & Cardiac Centre, Branch Street 2 - Lahore - ⭐ 4.5
# ✅ Dr. Zain Mehmood Butt Cardiologist, Lahore - 5.0(5) - Doctor · CARDIOLOGY Clinic, Ever Care Hospital, D1 commercial NECHS - Lahore - ⭐ 5.0
# ✅ Dr Zeeshan Malik - 5.0(8) - Cardiologist · Cardiology Department, University Of - Lahore - ⭐ 5.0
# ✅ Dr. Masood Sadiq Clinic - 4.4(112) - Pediatric cardiologist ·  · F7JX+HHQ, Maulana Shaukat Ali Rd - Lahore - ⭐ 4.4
# ✅ Dr Faisal Usman Ghani (Consultant Cardiologist) - 5.0(8) - Cardiologist · Ghazi, Airport road, Near New Butt sweet , Bhata chowk, Road - Lahore - ⭐ 5.0
# ✅ Dr Salman A shah - Child Heart Surgeon - 5.0(11) - Surgeon ·  · Ittifaq St - Lahore - ⭐ 5.0
# ✅ Dr Umer Cardiologist - No reviews - Cardiologist · Rehmatul lil Alameen institute of Cardiology,(Social security Multan road, Lahore Multan Chungi - Lahore - ⭐ Not Available
# ✅ Dr. Pervaiz Akhtar Chaudhry - Best Cardiac Surgeon in Lahore - 5.0(7) - Surgeon · Plot No. 393-396 & 423-426, Street 2 - Lahore - ⭐ 5.0
# ✅ Dr Moazzam Baig Mirza Clinic - 4.4(25) - Doctor ·  · 15 Main Boulevard Garden Town - Lahore - ⭐ 4.4
# ✅ Dr Asim Riaz. Consultant Cardiologist - 4.0(4) - Medical clinic · 96 Jail Rd - Lahore - ⭐ 4.0
# ✅ Dr Ahmad Noman Clinic - No reviews - Cardiologist · G8PP+W87 - Lahore - ⭐ Not Available
# ✅ Dr Bismah Ejaz Health Clinic | Cardiologist - 5.0(2) - Medical clinic · House # 347 Sector A , Askari X - Lahore - ⭐ 5.0
# ✅ Dr. Hafiz Sohail Yousaf - No reviews - Cardiologist · 387-E Khayaban-e-Firdousi - Lahore - ⭐ Not Available
# ✅ Dr BILAL ISMAIL CHAUDHARY HEART SPECIALIST / CARDIAC SURGEON / CARDIOLOGIST - No reviews - Cardiologist · 44-L Street VIII - Lahore - ⭐ Not Available
# 🔚 No more pages for Lahore
#
# 🔍 Searching: Neurologists in  Lahore
# ✅ Dr Imad ud din Yousaf Butt Neurologist - Lahore, Pakistan - 4.9(663) - Neurologist ·  · Executive clinic Fatima Memorial Hospital - Lahore - ⭐ 4.9
# ✅ Dr. Rashid Imran - 4.3(32) - Neurologist ·  · Hameed Latif Hospital, 14 - Lahore - ⭐ 4.3
# ✅ Dr. Shahid Mukhtar - 4.3(18) - Neurologist ·  · 3, Main Blvd Allama Iqbal Town - Lahore - ⭐ 4.3
# ✅ Dr Adnan Hameed Gill Neurologist - 5.0(16) - Neurologist ·  · Plot No. 393-426, Omer Hospital and Cardiac Centre, Street 2 - Lahore - ⭐ 5.0
# ✅ Dr. Habib Sultan, Best Neurosurgeon in Lahore, pakistan - 4.9(98) - Neurosurgeon ·  · Habib Brain and spine centre, khan lab and diagnostic centre, lahore, 138, shadman 2, jail road, lahore - Lahore - ⭐ 4.9
# ✅ Dr Ayesha Aslam - 5.0(7) - Neurologist ·  · Evercare hospital - Lahore - ⭐ 5.0
# ✅ Dr.Syed Arslan Haider.Neurologist - 5.0(9) - Neurologist · 24,25, 26 Maulana Shaukat Ali Rd - Lahore - ⭐ 5.0
# ✅ Dr.Abubakar Siddique - 4.3(6) - Physical therapist ·  · F948+V8R - Lahore - ⭐ 4.3
# ✅ Dr.altaf neurologist - 5.0(1) - Neurologist · F7F2+X9F - Lahore - ⭐ 5.0
# ✅ Dr. Farrukh Ali Chaudhry - Neurologist - 5.0(6) - Neurologist ·  · G84J+449، Masood Hospital 99 - Lahore - ⭐ 5.0
# ✅ Dr. Tariq Salahuddin - 4.5(45) - Neurosurgeon ·  · 31-A, Nisar Colony, Khurshid Alam Road, Cantonment. - Lahore - ⭐ 4.5
# ✅ Dr. Waqas Mehdi - Neurosurgeon/Asst. Professor. Lahore, Pakistan - 4.2(48) - Neurologist ·  · 3-A، MID CITY HOSPITAL، Main Jail Rd، opposite Kinnard College - Lahore - ⭐ 4.2
# ✅ Dr Qasim Bashir - 4.2(37) - Doctor ·  · 18 - Lahore - ⭐ 4.2
# ✅ Dr Rashid Chaudhry Pain and Stress Clinic - 4.9(9) - Neurologist ·  · 88 Shah Jamal Rd - Lahore - ⭐ 4.9
# 🔚 No more pages for Lahore
#
# 🔍 Searching: Nephrologists in  Lahore
# ✅ Dr Aurangzeb Afzal's (Nephrologist) J.A. KIDNEY and Hypertension (Blood Pressure & Dialysis) Centre - 4.9(353) - Nephrologist ·  · Ihsan Mumtaz Hospital 71 block E, Jauhar Town، Maulana Shaukat Ali Rd، - Lahore - ⭐ 4.9
# ✅ Dr. Mateen Akram | Best Nephrologist in Lahore - 5.0(7) - Nephrologist ·  · F79X+R5R, Allah Hoo Chowk - Lahore - ⭐ 5.0
# ✅ Dr Yasir Hussain ( Nephrologist in Lahore ) Kidney Specialist & Blood Pressure Expert - 4.7(46) - Doctor ·  · MSK Hospital - Lahore - ⭐ 4.7
# ✅ Dr. Faheem Usman Sulehri , Best Nephrologist in Lahore - 5.0(6) - Nephrologist ·  · Phase 5, 153/1 - Lahore - ⭐ 5.0
# ✅ Dr. Muhammad Salman Rehman (Nephrologist) - 5.0(36) - Medical clinic · F7HJ+V49 Doctors Hospital & Medical Center - Lahore - ⭐ 5.0
# ✅ Dr Shafiq Cheema-BestNephrologist-Clinic - 3.9(45) - Doctor ·  · F Block Phase 5, 153/1 - Lahore - ⭐ 3.9
# ✅ Dr Bilal Rasool Ramay(Nephrologist) - 5.0(20) - Nephrologist ·  · FCV3+RF5, New Gourmet Bakery, Bedian Rd, beside Royal Palace Marriage Hall - Lahore - ⭐ 5.0
# ✅ Dr. Muhammad Mohsin Riaz - 5.0(11) - Nephrologist ·  · Plot no 393-396 & 423-426, D Block Johar - Lahore - ⭐ 5.0
# ✅ Dr. Faheem Usman Sulehri - 4.0(1) - Doctor ·  · Central Park Teaching Hospital, 31-KM Lahore – Kasur Rd - Lahore - ⭐ 4.0
# ✅ Dr. Muhammad Aamir (MBBS, FCPS-Nephrology) - 4.0(4) - Nephrologist ·  · Hameed Latif Hospital (Garden Town), 14 - Lahore - ⭐ 4.0
# ✅ Drifti Nephrology and Medical Center - 5.0(7) - Hospital ·  · Plot 145 - Lahore - ⭐ 5.0
# ✅ Dr. Awais Zaka, MD, FACP - Consultant Nephrologist - 5.0(1) - Nephrologist · Expert Consult Clinic of Lahore, 627 Khayaban-e-Jinnah - Lahore - ⭐ 5.0
# ✅ Dr Umer Razaq Best Child Kidney Specialist/Pediatric Nephrologist - 5.0(8) - Hospital ·  · 3-A Shadman II, opposite Kinnaird College Jail, road - Lahore - ⭐ 5.0
# ✅ Dr. Fowad Shahzad- American Obesity - Weight Loss Consultant | Diabetologist - Endocrinologist - Nephrologist - 4.9(76) - Health consultant ·  · Avenue Mall, Ghazi Rd - Lahore - ⭐ 4.9
# ✅ Dr Azeem Baig Nephrologist - No reviews - Nephrologist ·  · 12 - Lahore - ⭐ Not Available
# ✅ Dr. Shahbaz Parvaiz - 5.0(1) - Nephrologist · Chauburji - Lahore - ⭐ 5.0
# ✅ Dr Abad-ur-Rehman Nephrologist - No reviews - Hospital ·  · G8QP+2W5, Jail Rd - Lahore - ⭐ Not Available
# ✅ Dr Azeem Baig Nephrologist - No reviews - Nephrologist - Lahore - ⭐ Not Available
# ✅ Dr Adnan Sulehri - No reviews - Nephrologist · F932+RP3 General Hospital - Lahore - ⭐ Not Available
# ✅ Dr Abid Abbas | Best Urologist Kidney Specialist - 5.0(3) - Urologist ·  · M, Centre, Saira memorial Hospital, Block Civic - Lahore - ⭐ 5.0
# ✅ Dr. Nasir Ibraahim | Best Kidney Transplant Surgeon in Lahore - 5.0(1) - Urologist ·  · F88V+RHC Shaikh Zayed Hospital - Lahore - ⭐ 5.0
# ✅ Dr. Mujtaba Chaudhry-Consultant Nephrologist - No reviews - Nephrologist - Lahore - ⭐ Not Available
# 🔚 No more pages for Lahore
#
# 🔍 Searching: Endocrinologists in  Lahore
# ✅ Dr. Muhammad Murtaza Shafqat - Endocrinologist & Diabetologist - 5.0(61) - Endocrinologist · Hameed Latif Hospital - Lahore - ⭐ 5.0
# ✅ Dr.Uzma Malik, Lahore Endocrine, Diabetes & Thyroid Clinic (LEDC) - 4.7(79) - Endocrinologist ·  · 114, Main Sutlej Avenue, PGECHS, Nespak Housing Society Phase1 - Lahore - ⭐ 4.7
# ✅ Dr Awais Muhammad Butt - Endocrinologist & Diabetologist - 5.0(1) - Endocrinologist · Omar Hospital and Cardiac Centre, Jail Rd - Lahore - ⭐ 5.0
# ✅ Dr. Fowad Shahzad- American Obesity - Weight Loss Consultant | Diabetologist - Endocrinologist - Nephrologist - 4.9(76) - Health consultant ·  · Avenue Mall, Ghazi Rd - Lahore - ⭐ 4.9
# ✅ Dr Fahad Khawaja - 5.0(8) - Endocrinologist · Plot 411Block G Gulshan, e Ravi - Lahore - ⭐ 5.0
# ✅ Dr Qurban Hussain Diabetologist & Endocrinologist in Lahore - 4.3(4) - Endocrinologist ·  · Al-Ghani Dental and medical center, 12-B BOR Main Rd, near Allah Ho Chowk - Lahore - ⭐ 4.3
# ✅ Dr Amena Endocrinology Clinic - 5.0(1) -  · 15 Main Boulevard Gulberg - Lahore - ⭐ 5.0
# ✅ Dr. Nabila Awais Razzaque-(Best Diabetologist & Hepatologist Lahore ) - 5.0(1) - Endocrinologist · 7, near Khokhar Chowk - Lahore - ⭐ 5.0
# ✅ Dr. Maria Saigol (Diabetes Specialist) - 5.0(17) - Diabetologist ·  · Akram Eye Hospital, D.H.A. Main Blvd - Lahore - ⭐ 5.0
# ✅ Dr Qamar Sajad - 5.0(1) - Endocrinologist · H9GH+4W - Lahore - ⭐ 5.0
# ✅ Dr Nauman Anjum Medical specialist & Diabetologist - 5.0(13) - Diabetologist ·  · 393-394 block D II johar town Johar - Lahore - ⭐ 5.0
# ✅ Dr. AMINA Riaz - 5.0(6) - Doctor · Wilcare Hospital - Lahore - ⭐ 5.0
# ✅ Dr. Maria Saigol (Diabetes Specialist) - 5.0(19) - Diabetologist · 154 CCA DD, adj. NADRA Office - Lahore - ⭐ 5.0
# ✅ Dr. Warda Diabetes & Medicine clinic - 4.6(11) - Medical clinic · Crown Complex, 31 A Queen's Road - Lahore - ⭐ 4.6
# ✅ Dr Awais Sugar Control Center - 4.2(10) - Health consultant · near Govt Junior Model School - Lahore - ⭐ 4.2
# ✅ Dr Awais Muhammad Butt - 5.0(9) - Endocrinologist ·  · Naeem Surgical Hospital (Executive Block Punjab Cooperative Housing Society, Ghazi Rd - Lahore - ⭐ 5.0
# ✅ Dr. Jehangir Abbas - 5.0(6) - Doctor · 131 St. 5 - Lahore - ⭐ 5.0
# ✅ Dr Amanullah Clinic - 4.9(21) - Endocrinologist ·  · Islamabad Diagnostic Centre (IDC, Main Jail Rd, near KFC - Lahore - ⭐ 4.9
# ✅ Dr. Muhammad Ali Awan Clinic - 4.6(97) - Specialized clinic ·  · 142 Allama Iqbal Road, Canal Rd - Lahore - ⭐ 4.6
# ✅ Dr.Fatima Mehboob Clinic - 4.4(9) - Medical clinic ·  · Excise & Taxation, 20 Abdul Sattar Edhi Rd, near Peace Home Society - Lahore - ⭐ 4.4
# ✅ Dr.Javed - No reviews - Endocrinologist · G79P+22C باجوا ہسپتال, Hafeez Taaib Rd - Lahore - ⭐ Not Available
# ✅ Dr. Maria Saigol (Diabetes Specialist) - 5.0(7) - Diabetologist · Diabetes Wellness Center, 200-Y Commercial Area - Lahore - ⭐ 5.0
# 🔚 No more pages for Lahore
#
# 🔍 Searching: Gastroenterologists in  Lahore
# ✅ Dr Habib Raja MBBS , FCPS , Gastroenterologist in Lahore - 4.9(164) - Gastroenterologist ·  · 7 - Lahore - ⭐ 4.9
# ✅ Dr. Mujahid Israr | Best Gastroenterologist in Lahore - 4.7(75) - Gastroenterologist ·  · National Hospital & Medical Center, 132/2 Street 123 - Lahore - ⭐ 4.7
# ✅ Dr. Muhammad Haseeb Nawaz | Best Gastroenterologist In Lahore | MBBS,MCPS (MEDICINE) ,FCPS (GASTRO) ,MACG, MASGE - 4.9(103) - Gastroenterologist · Salam Medical Complex, 320 Lahore – Kasur Rd - Lahore - ⭐ 4.9
# ✅ Dr. Mujahid Israr | Best Gastroenterologist in Lahore - 4.9(151) - Gastroenterologist ·  · Omar Hospital & Cardiac Centre, Jail Rd - Lahore - ⭐ 4.9
# ✅ Dr. Nouman Hameed | M.B.B.S., F.C.P.S. (Gasto)| Best Gastroenterologist in Lahore | Endoscopy, Colonoscopy, ERCP Specialist - 4.9(67) - Gastroenterologist ·  · Iffat Anwar Medical Complex, near Wapda town - Lahore - ⭐ 4.9
# ✅ Dr Fahd Aziz Rana - 4.5(125) - Gastroenterologist ·  · Plot No. 393-396 & 423-426, Omar Hospital, Street 2 - Lahore - ⭐ 4.5
# ✅ Dr Usman Naeem's Liver and Endoscopy | Best Gastroenterologist Clinic in Lahore - 4.9(131) - Gastroenterologist · Aadil Hospital, D.H.A. Main Blvd - Lahore - ⭐ 4.9
# ✅ Dr Salman Javed Gastroenterologist | Gut and Liver Care - 4.8(513) - Gastroenterologist ·  · 82 A - Lahore - ⭐ 4.8
# ✅ Dr Tariq Ahmed ( Best Gastroenterologist/ Liver Specalist)( Endoscopy/ Colonoscopy/ ERCP)معدہ جِگر لبلبہ اور انت اسپیشلسٹ - 4.9(148) - Gastroenterologist ·  · House No، 50-A Khayaban-e-Jamia Punjab - Lahore - ⭐ 4.9
# ✅ Dr Raja Ikram ul Haq. Assistant Professor Gastroenterology - 5.0(249) - Gastroenterologist · Sector L DHA phase 1 - Lahore - ⭐ 5.0
# ✅ Dr. Habib Raja | Best Gastroenterologist in Lahore - 5.0(20) - Gastroenterologist ·  · 17 - Lahore - ⭐ 5.0
# ✅ Dr Muhammad Awais Abid Consultant Physician & Gastroenterologist - 4.8(211) - Gastroenterologist ·  · Midcity hospital jail road, 7.30 9.30 - Lahore - ⭐ 4.8
# ✅ Dr. Muhammad Sufyan Asim Gastroenterologist & Diabetologist - 5.0(89) - Gastroenterologist ·  · H9J8+V6, Mian Rasheed Rd - Lahore - ⭐ 5.0
# ✅ Dr Tariq Ahmed ( Best Gastroenterologist/ Liver Specialist(Endoscopy/ Colonoscopy/ ERCP) معدہ جِگر لبلبہ و آنت اسپیشلسٹ - 5.0(6) - Gastroenterologist · Lane 13 - Lahore - ⭐ 5.0
# ✅ Dr Mian Asim Masood (Gastroenterologist & Transplant Hepatologist) - 5.0(10) - Gastroenterologist · 155 C1 - Lahore - ⭐ 5.0
# ✅ Dr. Faisal Masood - Consultant Physician & Gastroenterologist - 5.0(76) - Doctor ·  · 24, 25, 26 Maulana Shaukat Ali Rd - Lahore - ⭐ 5.0
# ✅ Dr Muhammad Shahzad Hafeez - 5.0(119) - Gastroenterologist · surgimed hospital zafar Ali road gulberg 5 Lahore, Al Hafeez Clinic saddar round about zarar shaheed road - Lahore - ⭐ 5.0
# ✅ Dr usama faizan Gastroenterologist - 5.0(22) - Health consultant · Shalamar hospital, Shalimar Link Road - Lahore - ⭐ 5.0
# ✅ Dr.Fatima Mehboob Clinic - 4.4(9) - Medical clinic ·  · Excise & Taxation, 20 Abdul Sattar Edhi Rd, near Peace Home Society - Lahore - ⭐ 4.4
# ✅ Dr. Arslan Shamim best diabetes stomach and liver specialist - 4.9(48) - Gastroenterologist · G8MV+X55 Ammar Medical Complex:, Jail Rd, Gulberg V, Lahore, Punjab 54000 Private - Lahore - ⭐ 4.9
# ✅ Dr.Muhammad AwaisAbid gastroenterologist - 5.0(27) - Hospital · H8PP+6VG, Akbar Rd, near Chugtai Lab - Lahore - ⭐ 5.0
# ✅ Dr Mujtaba Jaffary - 4.7(6) - Gastroenterologist ·  · Times Hospital,Allama Shabbir Usmani Road, 146-A/GOR-V,opp. JInnah hospital,Faisal Town - Lahore - ⭐ 4.7
# ✅ Dr. Ammar Arshad (Consultant Physician,Medical Specialist,Gastroenterologist,Endoscopist),MBBS(KE),FCPS(Medicine),MRCP(UK) - 5.0(9) - Doctor · Fatima Memorial Hospital - Lahore - ⭐ 5.0
# ✅ Dr. M Sufyan Asim Gastroenterologist - 5.0(4) - Gastroenterologist ·  · H9J5+9RW - Lahore - ⭐ 5.0
# ✅ Dr Hafsa Farooq - 5.0(27) - Doctor - Lahore - ⭐ 5.0
# ✅ Dr. Muhammad Bilal Nasir - 4.3(4) - Gastroenterologist · F7MX+2F4, Street 26 - Lahore - ⭐ 4.3
# 🔚 No more pages for Lahore
#
# 🔍 Searching: Oncologists in  Lahore
# ✅ Dr. Hassan Oncologist - 4.7(69) - Doctor ·  · New OPD, National Defense Hospital, 133 Street 153 - Lahore - ⭐ 4.7
# ✅ Dr Muhammad Arif oncologist and Hematologist .Razia sultana Memorial Cancer center - 3.6(5) - Oncologist ·  · 32 B, nazria e pakistan road Shaukat Khanum Hospital Rd - Lahore - ⭐ 3.6
# ✅ Dr Nazish Khalid | Best Gynecologic Oncologist in Lahore - 4.8(21) - Oncologist ·  · 152-G, 1 Canal Rd - Lahore - ⭐ 4.8
# ✅ Dr Imran Abdullah Oncologist (cancer Specialist) - 4.9(29) - Oncologist ·  - Lahore - ⭐ 4.9
# ✅ Dr Arif Ch. Oncologist Hematalogist - 5.0(17) - Doctor ·  · Plot 32 B, Nazaria - e- Pakistan Avenue, Service Rd, near Al Noor Eye Center - Lahore - ⭐ 5.0
# ✅ Dr. Sobia Yaqub-Oncologist/Cancer specialist - 5.0(12) - Oncologist - Lahore - ⭐ 5.0
# ✅ Dr Ahmad Farooq - 5.0(21) - Oncologist ·  · Bajwa Hospital, 356 Hafeez Taib Road - Lahore - ⭐ 5.0
# ✅ Dr. Anam Siddique - 4.8(9) - Oncologist · Jail, V, Ammar medical complex, road - Lahore - ⭐ 4.8
# ✅ Dr. Somer Masood (Surgical Oncologist, Breast Oncoplastic Surgeon, Reconstructive Surgeon, Advanced Laparoscopic Surgeon) - 4.9(47) - Surgeon ·  · Mid City Hospital, Main Jail Rd - Lahore - ⭐ 4.9
# ✅ Dr. Zainab Zubair - 5.0(49) - Surgeon ·  - Lahore - ⭐ 5.0
# ✅ Dr.Syed Nasir Abbas Bukhari - 4.7(16) - Pediatric oncologist · Street 123 - Lahore - ⭐ 4.7
# ✅ Dr Abdul Hameed, MBBS, MRCP, MD, FRCP,Consultant Haematologist - 3.8(5) - Hematologist · Ittefaq Hospital - Lahore - ⭐ 3.8
# ✅ Dr Sadia Sadiq , Consultant Clinical Oncologist - 5.0(6) - Health consultant · Chohan Tower, Jail Rd - Lahore - ⭐ 5.0
# ✅ Dr Ehsan Ur Rehman Clinic - 4.0(52) - Children's hospital ·  · G8Q4+CRJ - Lahore - ⭐ 4.0
# 🔚 No more pages for Lahore
#
# 🔍 Searching: Hematologists in  Lahore
# ✅ Dr Abdul Hameed, MBBS, MRCP, MD, FRCP,Consultant Haematologist - 3.8(5) - Hematologist · Ittefaq Hospital - Lahore - ⭐ 3.8
# ✅ Dr Arif Ch. Oncologist Hematalogist - 5.0(17) - Doctor ·  · Plot 32 B, Nazaria - e- Pakistan Avenue, Service Rd, near Al Noor Eye Center - Lahore - ⭐ 5.0
# ✅ Dr.Syed Nasir Abbas Bukhari - 4.7(16) - Pediatric oncologist · Street 123 - Lahore - ⭐ 4.7
# ✅ Dr. Hassan Oncologist - 4.7(69) - Doctor ·  · New OPD, National Defense Hospital, 133 Street 153 - Lahore - ⭐ 4.7
# ✅ Dr Muhammad Arif oncologist and Hematologist .Razia sultana Memorial Cancer center - 3.6(5) - Hematologist ·  · 32 B, nazria e pakistan road Shaukat Khanum Hospital Rd - Lahore - ⭐ 3.6
# ✅ Dr. Shahid Mahmood MD Hematology, Consultant Hematologist - No reviews - Consultant · Ravi, Riaz Mansoor Trust Hospital 239, Gulshan - Lahore - ⭐ Not Available
# ✅ Dr Fatima - 4.0(4) - Doctor · C8GW+Q4H, Unnamed Road - Lahore - ⭐ 4.0
# ✅ Dr. Nauman Siddique - 4.0(4) - Doctor · B-365 - Lahore - ⭐ 4.0
# ✅ Dr Imran Abdullah Oncologist (cancer Specialist) - 4.9(29) - Oncologist ·  - Lahore - ⭐ 4.9
# ✅ Dr Farooq Ahmed Janjua - No reviews - Doctor · H89V+9CM, Farooq St - Lahore - ⭐ Not Available
# 🔚 No more pages for Lahore
#
# 🔍 Searching: Pulmonologists in  Lahore
# ✅ Dr. Abdur Rahman Chest Specialist (Lahore) - 4.9(141) - Pulmonologist ·  · Horizon Hospital, 402 Bahria University Rd - Lahore - ⭐ 4.9
# ✅ Dr. Yasir Nasir Pulmonologist in Lahore - 4.5(26) - Pulmonologist ·  · 7 - Lahore - ⭐ 4.5
# ✅ Dr. Yasir Nasir, Chest Specialist, Best Pulmonologist, Sarcoidosis, COPD Specialist, Asthma Specialist - 4.5(2) - Pulmonologist ·  · 15 Jail Rd, opposite Kinnard College - Lahore - ⭐ 4.5
# ✅ Dr Amdad Faruqi (Consultant Physician n Pulmonologist) - 4.9(141) - Health consultant · Midcity Hospital, Jail Rd - Lahore - ⭐ 4.9
# ✅ Dr Asif Hanif Clinic - 4.5(29) - Doctor ·  · Samanabad Lahore Pakistan Bastami Rd, Bastami Road Samanabad Lahore Pakistan Bastami Rd - Lahore - ⭐ 4.5
# ✅ Dr. Asim Ahmed - Consultant Pulmonologist - No reviews - Pulmonologist · Faisal - Lahore - ⭐ Not Available
# ✅ Dr. Atif Mahmood - 4.0(20) - Pulmonologist ·  · H83P+96G، Kannan Clinic Aiwani tajarat - Lahore - ⭐ 4.0
# ✅ Dr Khawar Abbass - 4.1(9) - Pulmonologist ·  · G9Q2+6CX - Lahore - ⭐ 4.1
# ✅ Dr. Tanveer UL Islam Chest Specialist - 3.8(28) - Doctor ·  · 35-B - Lahore - ⭐ 3.8
# ✅ Dr. Akhtar Ali Pulmonologist in Lahore - 5.0(4) - Health consultant · Shalamar hospital - Lahore - ⭐ 5.0
# ✅ Dr. Faisal Hassan Zahid - 4.0(5) - Pulmonologist · 152-G, Doctors Hospital & Medical Center, 1 Canal Rd - Lahore - ⭐ 4.0
# ✅ Dr.Sarah Javed (🥇Medical Specialist & consultant physician) - 5.0(130) - Pulmonologist · Vital Care Hospital, 50A commercial lane - Lahore - ⭐ 5.0
# ✅ Dr. Kamran Cheema's Clinic - 2.8(86) - Doctor ·  · 111 habitat,, Jail Rd - Lahore - ⭐ 2.8
# ✅ Dr Amdad A Faruqi (Faruqi Clinic, Skin Laser Centre) - 4.9(191) - Pulmonologist ·  · 53 A blcok Commercial, Lahore – Kasur Rd - Lahore - ⭐ 4.9
# ✅ Dr Muhammad Hussain - 5.0(1) - Medical clinic · H8HX+73C - Lahore - ⭐ 5.0
# ✅ Dr Syed Ali Mazhar naqvi - 1.0(1) - Pulmonologist · Plot C, Doctor hospital, 5 - Lahore - ⭐ 1.0
# 🔚 No more pages for Lahore
#
# 🔍 Searching: Hepatologists in  Lahore
# ✅ Dr. Muhammad Haseeb Nawaz | Best Gastroenterologist In Lahore | MBBS,MCPS (MEDICINE) ,FCPS (GASTRO) ,MACG, MASGE - 4.9(103) - Gastroenterologist · Salam Medical Complex, 320 Lahore – Kasur Rd - Lahore - ⭐ 4.9
# ✅ Dr Habib Raja MBBS , FCPS , Gastroenterologist in Lahore - 4.9(164) - Gastroenterologist ·  · 7 - Lahore - ⭐ 4.9
# ...
# ✅ Dr. Masood Alam - 3.0(2) - Pulmonologist ·  · 6C3X+5R4, Nishtar Rd - Multan - ⭐ 3.0
# ✅ Dr Salman Ayaz - 5.0(1) - Pulmonologist ·  · 6C4P+WPR - Multan - ⭐ 5.0
# ✅ Dr. Imran Sharif Ansari - 5.0(2) - Pulmonologist ·  · Rehman Medical Complex, Nishtar Rd - Multan - ⭐ 5.0
# ✅ Dr Malik Waseem Riaz (Consultant Pulmonologist Multan) - 5.0(6) - Consultant · 94, Al-Kamal Plaza IDC, Nishtar Rd - Multan - ⭐ 5.0
# ✅ Dr Rana Shahzad Kamal - No reviews - Pulmonologist · Chenab Hospital Chungi, 01 Suraj Miani Road - Multan - ⭐ Not Available
# ✅ Dr Shakeel Ahmad Khan - 3.0(2) - Pulmonologist · 6C3X+68C, Zawar Hussain Road - Multan - ⭐ 3.0
# ✅ Dr Abdul Hafeez Chest Clinic - 5.0(6) - Doctor ·  · Rashid Minhas Rd, opposite Naz Cinema - Multan - ⭐ 5.0
# 🔚 No more pages for Multan
#
# 🔍 Searching: Hepatologists in  Multan
# ✅ Dr. Waseem Sarwar Malghani - 4.0(8) - Gastroenterologist ·  · OPD, Medicare Hospital, 62-A Abdali Rd - Multan - ⭐ 4.0
# ✅ Dr.muhammad Naveed aslam gastroenterology Fatima medical center Chowk rasheed Abad Multan - 5.0(18) - Gastroenterologist ·  · Dr.muhammad Naveed aslam gastroenterology Fatima medical center, 1 Chowk Rasheedabad Flyover - Multan - ⭐ 5.0
# ✅ Dr M Zubair A Khan (GI and Liver Clinic) - 4.5(11) - Health · 6C2X+XW7, Nishtar Rd - Multan - ⭐ 4.5
# ✅ Dr. Ibrar Ahmad Khan - 5.0(4) - Gastroenterologist · Khan Medical City, 16 Nishtar Rd - Multan - ⭐ 5.0
# ✅ Dr Zulqarnain Haider - 4.5(11) - Specialized hospital ·  · 6F5H+HQV Sqn Ldr, Sqn Ldr Sarfraz Rafiqui Shaheed - Multan - ⭐ 4.5
# ✅ Dr. Ghazi Khan Khosa - 4.7(20) - Pediatric gastroenterologist · 5C74+2WC, Sher Shah Road - Multan - ⭐ 4.7
# ✅ Dr. Farrukh Rizvi - 5.0(42) - Surgeon ·  · Buch International Hospital Buch Villas Bosan, Road - Multan - ⭐ 5.0
# ✅ Dr. Mumtaz Athar - 5.0(4) - Gastroenterologist ·  · 6C3X+8JJ - Multan - ⭐ 5.0
# ✅ Dr. Rabia Saleem Safdar (Child Specialist & Child Nephrologist) - 4.9(142) - Pediatrician ·  · 88/4Nasheman Colony Bosan Rd - Multan - ⭐ 4.9
# ✅ Dr. Junaid Riaz - 4.7(81) - Dermatologist ·  · 6C6P+8H9 - Multan - ⭐ 4.7
# ✅ Dr. Abid Hussain Diabetes And Liver Care - No reviews - Medical clinic ·  · Ground floor, Dost Plaza, Nishtar Rd - Multan - ⭐ Not Available
# 🔚 No more pages for Multan
#
# 🔍 Searching: Rheumatologists in  Multan
# ✅ Dr. Sajjad Raza Malik - 5.0(1) - Doctor · 6C3X+933, Zawar Hussain Road - Multan - ⭐ 5.0
# ✅ Dr M.Masood Tahir[FCPS(MEDICINE)&FCPS {میڈیکل اسپیشلسٹ اینڈ گیسٹروانٹرالوجسٹ}Ass. Professor Nishtar Hospital Multan - 5.0(15) - Specialized clinic ·  · Clinic 22 & 23, Khan Medical City, Nishtar Rd - Multan - ⭐ 5.0
# ✅ Dr Abdul Shakoor - 5.0(2) - Doctor · 5CPJ+MFM, Tipu Sultan Rd - Multan - ⭐ 5.0
# ✅ Dr Ghulam Mujtaba Clinic - 3.2(70) - Doctor ·  · 6F22+W87, Nishtar Rd - Multan - ⭐ 3.2
# ✅ Dr. Syed Ali Rukh Rheumatologist in Multan - No reviews - Doctor · MUKHTAR A SHEIKH HOSPITAL, KHANEWAL ROAD - Multan - ⭐ Not Available
# ✅ Dr Azmat Rasool Hadi Jorh Centre - 4.4(10) - Doctor ·  · 5FXQ+PX3 Ali Chowk, Masoom Shah Rd - Multan - ⭐ 4.4
# ✅ Dr Summaira Tariq MBBS,FCPS Best Gynaecologist Obstetrician & Infertility Expert-Hareem Gynae & Neuro Specialist Clinic - 5.0(10) - Obstetrician-gynecologist ·  - Multan - ⭐ 5.0
# ✅ Dr. Sufyan Saleem Safdar - 5.0(2) - Pulmonologist ·  · 62 A Abdali Rd - Multan - ⭐ 5.0
# ✅ Dr Abdul Rauf - 4.0(2) - Doctor ·  · 6C3X+67C, Nishtar Rd - Multan - ⭐ 4.0
# ✅ Dr. Waseem Sarwar Malghani - 4.0(8) - Gastroenterologist ·  · OPD, Medicare Hospital, 62-A Abdali Rd - Multan - ⭐ 4.0
# ✅ Dr. Muneer Ahmad Chaudhary - No reviews - Pain control clinic · 6G44+C38, Masoom Shah Rd - Multan - ⭐ Not Available
# ✅ Dr. Mudasir/Mubashir Husnain Lodge - No reviews - Doctor · 6FHJ+R8H, Street No. 4 - Multan - ⭐ Not Available
# 🔚 No more pages for Multan
#
# 🔍 Searching: Orthopedic Surgeons in  Multan
# ✅ Dr. Rizwan Ghafoor, Orthopaedic Surgeon - 4.9(110) - Orthopedic surgeon ·  · Fatima Medical Centre, Chowk Rasheedabad Flyover - Multan - ⭐ 4.9
# ✅ Dr Usman Saleem FRCS(UK) Orthopaedic Surgeon - 5.0(5) - Orthopedic clinic ·  · Medicare Hospital, 62-A Abdali Rd - Multan - ⭐ 5.0
# ✅ Dr Irfan Qadir Orthopaedic and Arthroscopy Surgeon - 4.5(8) - Orthopedic surgeon ·  · 62A Abdali Rd - Multan - ⭐ 4.5
# ✅ Dr Mahmood Ahmad - Best Spine Surgeon, TB Spine, Scoliosis. - 5.0(33) - Surgeon ·  · Eid Gaah Chowk, 17-E - Multan - ⭐ 5.0
# ✅ Dr. Sheikh Ishfaq Ahmad - 4.5(2) - Orthopedic surgeon ·  · 6G53+VRF, Khanewal Rd - Multan - ⭐ 4.5
# ✅ Dr. Muhammad Ishfaq Malik - 5.0(2) - Orthopedic surgeon ·  · 2 Nishtar Rd - Multan - ⭐ 5.0
# ✅ Dr Rashid Farooq (Orthopaedic Surgeon) - 4.0(6) - Doctor ·  · Block, House No 4, Boulevard, A Model - Multan - ⭐ 4.0
# ✅ Dr Nasir Khan Bosan Orthopedic and Arthoscopy Surgeon - 4.7(6) - Health ·  · 6F69+PV9, La Salle Rd - Multan - ⭐ 4.7
# ✅ Dr Azhar Rasheed Orthopaedic and Joint Replacement Surgeon - 5.0(2) - Doctor ·  · Hamid Commercial centre Mobil Plaza, Main Vehari Rd - Multan - ⭐ 5.0
# ✅ Dr. Kamran Salik - 3.8(4) - Orthopedic clinic ·  · 6C4P+JJQ, Suraj Miani Road - Multan - ⭐ 3.8
# ✅ Dr. Farrukh Rizvi - 5.0(42) - Surgeon ·  · Buch International Hospital Buch Villas Bosan, Road - Multan - ⭐ 5.0
# ✅ Dr.adeel Orthopaedic surgeon - 5.0(1) - Health consultant · Al Khaliq Hospital, Nishtar Rd - Multan - ⭐ 5.0
# ✅ Dr. Hafiz Azhar Hussain - No reviews - Orthopedic surgeon ·  · 6C3X+9P6 Dost Medical Complex, Nishtar Rd - Multan - ⭐ Not Available
# ✅ Dr. Matloob Ahmad - 5.0(1) - Orthopedic clinic ·  · near Subhani pharmacy - Multan - ⭐ 5.0
# ✅ Dr Azmat Rasool Hadi Jorh Centre - 4.4(10) - Doctor ·  · 5FXQ+PX3 Ali Chowk, Masoom Shah Rd - Multan - ⭐ 4.4
# ✅ Dr Nosheen Tariq Clinic - 3.7(3) - Doctor ·  · 5FX2+MH2, Old Bahawalpur Rd - Multan - ⭐ 3.7
# ✅ Dr M. Tahir Karim - No reviews - Orthopedic surgeon · Bakhtawar Amin Memorial Trust Hospital, Northern Byp - Multan - ⭐ Not Available
# ✅ Dr. Muhammad Arshad Joiya - 5.0(4) - Orthopedic surgeon ·  · Clinic 94, Islamabad Diagnostic Centre, Al-Kamal Plaza, Nishtar Rd, opp. Dost Plaza - Multan - ⭐ 5.0
# ✅ Dr azhar Hussain - 5.0(4) - Hospital ·  · 6C3X+H3F Sara Wali Gali - Multan - ⭐ 5.0
# ✅ Dr. Zafar Iqbal Malik - 5.0(2) - Surgeon ·  · 4 Nishtar Rd - Multan - ⭐ 5.0
# ✅ Dr Nur Saeed General Surgeon - 5.0(1) - Health ·  · 6F69+PW3 - Multan - ⭐ 5.0
# ✅ Dr. Nasir Mehmood Neuru Clinic - 4.3(7) - Neurosurgeon ·  · 6F22+X23 Waseem Square, Nishtar Rd - Multan - ⭐ 4.3
# ✅ Dr Syed Shahid Bokhari Brain and Spine Clinic - 5.0(13) - Neurosurgeon ·  · Medicare Hospital, 62A Abdali Rd - Multan - ⭐ 5.0
# ✅ Dr Salman Farid - 4.9(126) - Neurologist ·  · City Hospital - Multan - ⭐ 4.9
# 🔚 No more pages for Multan
#
# 🔍 Searching: Urologists in  Multan
# ✅ Dr. Muhammad Waqas Khan MBBS, FCPS, FRCS(UK) FACS (USA)Best Urologist, Sexologist, General surgeon & physican ,Andrologist & Male Sexual Health Specialist in Pakistan - 4.6(38) - Urologist ·  · Metro Station New Multan Road, near Jinnah Park - Multan - ⭐ 4.6
# ✅ Dr. Zeeshan Arshad - 5.0(1) - Urologist ·  · 6C2X+XWP Al Khaliq Hosptal - Multan - ⭐ 5.0
# ✅ Dr. Rana Atta ur Rehman - 5.0(2) - Urologist ·  · 4 Nishtar Rd - Multan - ⭐ 5.0
# ✅ Dr Fazal ur Rehman Urology Clinic - 4.3(6) - Urology clinic ·  · Chenab General Hospital Room 110 First Floor Chungi no, 1 Suraj Miani Road - Multan - ⭐ 4.3
# ✅ Dr. Qadeer Ahmad Tariq - 5.0(1) - Urologist ·  · 6C2X+WP5, Nishtar Rd - Multan - ⭐ 5.0
# ✅ Dr. Ahmad Salman - 4.8(9) - Consultant · South Punjab Hospital, Suraj Miani Road - Multan - ⭐ 4.8
# ✅ Dr Muhammad Adnan ch urologist and sexologist - No reviews - Urologist · Medicare Hospital, Abdali road - Multan - ⭐ Not Available
# ✅ Dr Naeem Urology Clinic - No reviews - Urology clinic · 6C4P+JFW, Ghouse Azam Road - Multan - ⭐ Not Available
# ✅ Dr. Muhammad Yousif - 5.0(1) - Nephrologist ·  · Haleema Medical Complex - Multan - ⭐ 5.0
# ✅ Dr Nadeem Ansari Kidney specialist - 5.0(4) - Hospital ·  · 6G65+547 - Multan - ⭐ 5.0
# ✅ Dr M Shahzeb Asghar, The Laparoscopic Surgeon in Multan - 5.0(11) - Doctor · Ibne Sina Hospital - Multan - ⭐ 5.0
# ✅ Dr.Tanveer Khan - 4.2(5) - Medical clinic ·  · 6G67+7G2, Khanewal Rd, near nadra office - Multan - ⭐ 4.2
# ✅ Dr. Abdul Ghaffar Clinic - 3.9(16) - Homeopathic pharmacy · 49PJ+2Q9, Mehdi Pur Road - Multan - ⭐ 3.9
# ✅ Dr. Tahir Naveed Home - 5.0(1) - Residents association · Mehmood, House 3, Muhammad Street, Mehmood Kot - Multan - ⭐ 5.0
# 🔚 No more pages for Multan
#
# 🔍 Searching: Ophthalmologists in  Multan
# ✅ Dr Asaad Saleem Punjab Eye Care - 5.0(91) - Ophthalmologist ·  · zainab arcade، Ghauri laboratory plaza, Nishtar Rd - Multan - ⭐ 5.0
# ✅ Dr. Majid Laser Eye Clinic - 4.7(6) - Ophthalmologist ·  · Near Chungi, 1 Suraj Miani Road - Multan - ⭐ 4.7
# ✅ Dr Jahanzeb Eye Care - No reviews - Ophthalmologist · 6F5Q+XR7, Chowk Rasheedabad Flyover - Multan - ⭐ Not Available
# ✅ Dr Ghulam Abbas - 5.0(1) - Ophthalmologist ·  · 6F6Q+39H Dr.ghulam abbas eye 👁️ surgeon Fatima medical center, Chowk Rasheedabad Flyover - Multan - ⭐ 5.0
# ✅ Dr Arslan Saleem - 4.1(7) - Eye care center ·  · Alaya Eye Care Clinic Multan Medical Complex, Suraj Miani Road, opposite South Punjab Hospital - Multan - ⭐ 4.1
# ✅ Dr. Manzoor Eye Clinic - 4.0(9) - Eye care center · 6F6J+7XG - Multan - ⭐ 4.0
# ✅ Dr Salman Eye Clinic - 5.0(5) - Eye care center ·  · 5CHX+828 - Multan - ⭐ 5.0
# ✅ Dr. Rashid Riaz Eye Care Clinic - 4.3(6) - Ophthalmologist · Zanib Plaza, Ghuri lab, 15 Nishtar Rd - Multan - ⭐ 4.3
# ✅ Dr Aasim Mehmood - 5.0(2) - Eye care center · 6FFG+G9G, Bosan Rd - Multan - ⭐ 5.0
# ✅ Dr. Hafiz Nadeem Ahmad , Aziz Retina & Health Care Center Eye Surgeon - 3.5(4) - Eye care center · Ghous e Azam Rd, near Chungi# 1 - Multan - ⭐ 3.5
# ✅ Dr. Irum Ahmad Raza - No reviews - Ophthalmologist · 6C3X+9JG - Multan - ⭐ Not Available
# ✅ Dr Najam Ul Hassan, Eye Care Pakistan, Consultant Eye Specialist & Eye Surgeon - 4.9(29) - Ophthalmologist - Multan - ⭐ 4.9
# ✅ Dr Ashraf Ali Tayyab - 5.0(2) - Hospital ·  · 6C3X+8JV - Multan - ⭐ 5.0
# ✅ Dr Salman Farid - 4.9(126) - Neurologist ·  · City Hospital - Multan - ⭐ 4.9
# 🔚 No more pages for Multan
#
# 🔍 Searching: Psychiatrists in  Multan
# ✅ Dr. Owais Kareem, MBBS, FCPS, Associate Professor and Head of Psychiatry Department, Nishtar Medical University - 4.9(120) - Psychiatrist · under Rasheedabad flyover, main Khanewal Rd - Multan - ⭐ 4.9
# ✅ Dr. A Sajjad Siddiqui - 3.9(15) - Psychiatrist ·  · 25-B - Multan - ⭐ 3.9
# ✅ Dr. M. Arshad Mujahid - 5.0(2) - Psychiatrist · Prince Hotel Street, Hussain Medical Center, Nishtar Rd - Multan - ⭐ 5.0
# ✅ Dr. Fehmida Shehzadi - 4.7(59) - Psychologist ·  · Seyal Medical center, Katchehry Road, near chowk - Multan - ⭐ 4.7
# ✅ Dr. Hafiz Shafique Ahmad, MBBS, MCPS, FCPS, Associate Professor - 5.0(5) - Psychiatrist · Jinnah Clinics, Nishtar Rd - Multan - ⭐ 5.0
# ✅ Dr. Tahir Feroze Khan - 4.5(2) - Psychiatrist · Nishtar Rd - Multan - ⭐ 4.5
# ✅ Dr.Haleema Psychologist - 3.5(4) - Psychologist - Multan - ⭐ 3.5
# ✅ Dr. Naeem Ullah Laghari - 3.7(25) - Physiatrist ·  · 6C6P+XGC, Suraj Miani Road - Multan - ⭐ 3.7
# ✅ Dr. Farah Rasheed-Consultant Psychiatrist - No reviews - Psychiatrist · Chenab Hospital, Suraj Miani Road - Multan - ⭐ Not Available
# ✅ Dr. A. Sajjad - 1.0(1) - Physiatrist ·  · 6C3X+9P8 Dost Medical Complex, Nishtar Rd - Multan - ⭐ 1.0
# ✅ Dr. Nadeem Ullah - 5.0(1) - Specialized clinic · 9 Hazori Bag Rd - Multan - ⭐ 5.0
# 🔚 No more pages for Multan
#
# 🔍 Searching: Psychologists in  Multan
# ✅ Dr. Fehmida Shehzadi - 4.7(59) - Psychologist ·  · Seyal Medical center, Katchehry Road, near chowk - Multan - ⭐ 4.7
# ✅ Dr. Owais Kareem, MBBS, FCPS, Associate Professor and Head of Psychiatry Department, Nishtar Medical University - 4.9(120) - Psychiatrist · under Rasheedabad flyover, main Khanewal Rd - Multan - ⭐ 4.9
# ✅ Dr.Haleema Psychologist - 3.5(4) - Psychologist - Multan - ⭐ 3.5
# ✅ Dr Syed Muzaffar Hussain Zaidi - 5.0(1) - Consultant · 560 Bosan Rd, near Bandesha Lodge - Multan - ⭐ 5.0
# ✅ Dr Beenish Abid Clinic - 5.0(1) - Psychologist · 6C3P+RXQ, Street No1, beside Millat school chungi - Multan - ⭐ 5.0
# ✅ Dr. A Sajjad Siddiqui - 3.9(15) - Psychiatrist ·  · 25-B - Multan - ⭐ 3.9
# ✅ Dr. M. Arshad Mujahid - 5.0(2) - Psychiatrist · Prince Hotel Street, Hussain Medical Center, Nishtar Rd - Multan - ⭐ 5.0
# ✅ Dr. Tahir Feroze Khan - 4.5(2) - Psychiatrist · Nishtar Rd - Multan - ⭐ 4.5
# ✅ Dr Irfan Anjum - No reviews - Psychologist · 6F8R+WXG - Multan - ⭐ Not Available
# 🔚 No more pages for Multan
#
# 🔍 Searching: Allergists in  Multan
# ✅ Dr. Sarmad Abdul Rehman khan - 5.0(11) - Pulmonologist ·  · Dost Plaza, Nishtar Rd - Multan - ⭐ 5.0
# ✅ Dr. Rabia Saleem Safdar (Child Specialist & Child Nephrologist) - 4.9(142) - Pediatrician ·  · 88/4Nasheman Colony Bosan Rd - Multan - ⭐ 4.9
# ✅ Dr. Liaqat Ali Dogar - 4.2(11) - Pulmonologist ·  · 4 Nishtar Rd - Multan - ⭐ 4.2
# ✅ Dr. Muhammad Aneel Razzaq - 5.0(8) - Pulmonologist ·  · 6F22+X22 Waseem Square, Nishtar Rd - Multan - ⭐ 5.0
# ✅ Dr. Junaid Riaz - 4.7(81) - Dermatologist ·  · 6C6P+8H9 - Multan - ⭐ 4.7
# ✅ Dr. Sufyan Saleem Safdar - 5.0(2) - Pulmonologist ·  · 62 A Abdali Rd - Multan - ⭐ 5.0
# ✅ Dr. Fiaz Hussain Hair Transplant & Skin Specialist - 4.4(14) - Dermatologist · 72 - B, adjacent to MCB Islamic & Habibmetro Bank - Multan - ⭐ 4.4
# ✅ Dr Shazia Zubair - 4.3(202) - Skin care clinic ·  · Burger King، 29-A, Opposite - Multan - ⭐ 4.3
# ✅ Dr Ghulam Mujtaba Clinic - 3.2(70) - Doctor ·  · 6F22+W87, Nishtar Rd - Multan - ⭐ 3.2
# ✅ Dr. Masood Alam - 3.0(2) - Pulmonologist ·  · 6C3X+5R4, Nishtar Rd - Multan - ⭐ 3.0
# ✅ Dr. Muhammad Hassan Nisar - 4.0(4) - Otolaryngologist ·  · Khan Medical City, 16 Nishtar Rd - Multan - ⭐ 4.0
# ✅ Dr Humayun Riaz Khan - 5.0(4) - Doctor ·  · Rehman medical centre, Nishtar Rd - Multan - ⭐ 5.0
# 🔚 No more pages for Multan
#
# 🔍 Searching: Immunologists in  Multan
# ---------------------------------------------------------------------------
# JavascriptException                       Traceback (most recent call last)
# Cell In[4], line 103
#     101 # **🔄 Scrolling Mechanism to Load More Results**
#     102 for _ in range(10):  # **Scroll 10 times**
# --> 103     driver.execute_script("document.querySelector('div[role=\"feed\"]').scrollBy(0, 1000);")
#     104     time.sleep(2)
#     106 retry_attempts = 3  # **Retry if no results**
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:528, in WebDriver.execute_script(self, script, *args)
#     525 converted_args = list(args)
#     526 command = Command.W3C_EXECUTE_SCRIPT
# --> 528 return self.execute(command, {"script": script, "args": converted_args})["value"]
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:429, in WebDriver.execute(self, driver_command, params)
#     427 response = self.command_executor.execute(driver_command, params)
#     428 if response:
# --> 429     self.error_handler.check_response(response)
#     430     response["value"] = self._unwrap_value(response.get("value", None))
#     431     return response
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# JavascriptException: Message: javascript error: Cannot read properties of null (reading 'scrollBy')
#   (Session info: chrome=134.0.6998.177)
# Stacktrace:
# 	GetHandleVerifier [0x010FC7F3+24435]
# 	(No symbol) [0x01082074]
# 	(No symbol) [0x00F506E3]
# 	(No symbol) [0x00F570D7]
# 	(No symbol) [0x00F595C5]
# 	(No symbol) [0x00FE0225]
# 	(No symbol) [0x00FBD7BC]
# 	(No symbol) [0x00FDF20A]
# 	(No symbol) [0x00FBD5B6]
# 	(No symbol) [0x00F8C54F]
# 	(No symbol) [0x00F8D894]
# 	GetHandleVerifier [0x014070A3+3213347]
# 	GetHandleVerifier [0x0141B0C9+3295305]
# 	GetHandleVerifier [0x0141558C+3271948]
# 	GetHandleVerifier [0x01197360+658144]
# 	(No symbol) [0x0108B27D]
# 	(No symbol) [0x01088208]
# 	(No symbol) [0x010883A9]
# 	(No symbol) [0x0107AAC0]
# 	BaseThreadInitThunk [0x75EE5D49+25]
# 	RtlInitializeExceptionChain [0x77AACE3B+107]
# 	RtlGetAppContainerNamedObjectPath [0x77AACDC1+561]

# %% [markdown]
# # ⚙️ How It Works
# Launches Chrome in headless mode.
#
# Iterates over cities and search queries.
#
# Performs search, scrolls results, and scrapes relevant details.
#
# Saves only listings starting with "Dr".
#
# Automatically stops after collecting 50,000 records.

# %% [markdown]
# ### 🧼 Doctor Dataset Cleaning & Categorization
#
# This notebook performs data cleaning and intelligent classification for a dataset of doctors in Pakistan. The main objectives of this code are:
#
# - 📥 **Load the raw doctors dataset** from a CSV file.
# - 🧹 **Clean the hospital/clinic addresses** by removing unwanted characters and standardizing the format.
# - 🔍 **Extract doctor specializations** using a combination of:
#   - Known medical titles and specialties (e.g., *Cardiologist*, *Dermatologist*)
#   - Disease-related keywords (e.g., *heart*, *skin*, *cancer*)
#   - Contextual clues from the doctor's name, address, or city fields
# - 🧠 **Apply intelligent pattern-matching** using regular expressions (`regex`) to assign the most likely medical category where it is missing or marked as "Unspecified".
# - 📊 **Convert ratings to numeric format** and ensure consistency in all fields.
# - 💾 **Export a cleaned and categorized version** of the dataset to `cleaned_doctors.csv`.
#
# By the end of this process, the dataset becomes cleaner, more structured, and better suited for analysis or use in healthcare-related applications.

# %%
import pandas as pd
import re

# Load dataset
df = pd.read_csv("doctors.csv") 

# Function to clean address/details
def clean_address(hospital_clinic_field):
    if pd.isna(hospital_clinic_field) or hospital_clinic_field.strip() == "":
        return "Location not listed"
    hospital_clinic_field = re.sub(r"[^a-zA-Z0-9,+.\-/\s]", "", hospital_clinic_field)
    hospital_clinic_field = re.sub(r"\s+", " ", hospital_clinic_field).strip()
    return hospital_clinic_field

# Expanded list of specializations and diseases to match using regex
specializations = [
    "Dermatologist", "Dental Surgeon", "Orthopedic Surgeon", "General Physician", 
    "Cardiologist", "Neurologist", "Psychiatrist", "Pediatrician", "Gynecologist", 
    "Plastic Surgeon", "Rheumatologist", "Pulmonologist", "Nephrologist", 
    "Hematologist", "Oncologist", "Ophthalmologist", "ENT Specialist", 
    "Endocrinologist", "Surgeon", "Gastroenterologist", "Allergist", "Infectious Disease Specialist",
    "Urologist", "Gastrointestinal Specialist", "Hepatologist", "Immunologist", "Rehabilitation Specialist", 
    "Pain Management Specialist", "Sports Medicine Specialist", "Emergency Medicine Specialist", 
    "Sleep Medicine Specialist", "Palliative Care Specialist", "Neonatologist", "Obstetrician", 
    "Family Medicine Specialist", "Family Physician", "Clinical Psychologist", "Dermatopathologist", 
    "Rheumatology Specialist", "Toxicologist", "Medical Geneticist", "Endoscopic Specialist", 
    "Pathologist", "Microbiologist", "Geriatric Specialist", "Addiction Specialist", "Thoracic Surgeon", 
    "Vascular Surgeon", "Pain Specialist", "Mental Health Specialist", "Plastic Surgeon", 
    "Geriatrics", "Acupuncture Specialist", "Psychotherapist", "Physical Therapist", "Naturopathic Doctor"
]

# List of common disease-related terms to capture
disease_terms = {
    "eye": "Ophthalmologist",
    "heart": "Cardiologist",
    "diabetes": "Diabetologist",
    "cancer": "Oncologist",
    "skin": "Dermatologist",
    "lung": "Pulmonologist",
    "kidney": "Nephrologist",
    "liver": "Hepatologist",
    "mental health": "Psychiatrist",
    "brain": "Neurologist",
    "obesity": "Endocrinologist",
    "blood": "Hematologist",
    "allergy": "Allergist",
    "infection": "Infectious Disease Specialist",
    "arthritis": "Rheumatologist",
    "pregnancy": "Gynecologist",
    "spinal": "Orthopedic Surgeon",
    "gastro": "Gastroenterologist",
    "sleep": "Sleep Medicine Specialist",
    "rehab": "Rehabilitation Specialist",
    "neurology": "Neurologist",
    "dentistry": "Dental Surgeon",
    "pediatrics": "Pediatrician",
    "obstetrics": "Obstetrician",
    "geriatric": "Geriatrician",
    "toxicology": "Toxicologist",
    "psychology": "Psychologist",
    "physiotherapy": "Physical Therapist",
}

# Define surgeon types to capture full specialization (Orthopedic, Dental, etc.)
surgeon_types = [
    "orthopedic", "dental", "neuro", "plastic", "cardiac", "vascular", "thoracic", "spinal"
]

# Normalize and search for specializations and diseases in the Name, Address, or City
def extract_specializations(name, address, city, current_category):
    name_lower = name.lower()
    address_lower = address.lower()
    city_lower = city.lower()

    # Check for diseases using disease_terms dictionary
    for term, category in disease_terms.items():
        if re.search(rf"\b{term}\b", name_lower) or re.search(rf"\b{term}\b", address_lower) or re.search(rf"\b{term}\b", city_lower):
            return category if current_category in ["Unspecified", "Unknown", None] else current_category

    # Search for skin-related terms (starting or ending with "skin")
    skin_terms = ["skin", "dermatologist", "skin specialist", "skin care", "skin doctor"]
    for term in skin_terms:
        if re.search(rf"\b{term}\b", name_lower) or re.search(rf"\b{term}\b", address_lower) or re.search(rf"\b{term}\b", city_lower):
            return "Dermatologist" if current_category in ["Unspecified", "Unknown", None] else current_category

    # Search for child-related terms (pediatric and similar terms)
    child_terms = ["pediatrician", "child specialist", "pediatric care", "pediatrics", "child doctor"]
    for term in child_terms:
        if re.search(rf"\b{term}\b", name_lower) or re.search(rf"\b{term}\b", address_lower) or re.search(rf"\b{term}\b", city_lower):
            return "Pediatrician" if current_category in ["Unspecified", "Unknown", None] else current_category

    # Search for surgeon types (Orthopedic, Dental, etc.) and assign full specialization
    for surgeon in surgeon_types:
        if re.search(rf"\b{surgeon}\b", name_lower) or re.search(rf"\b{surgeon}\b", address_lower) or re.search(rf"\b{surgeon}\b", city_lower):
            # Return the full specialization (e.g., "Orthopedic", "Dental")
            return surgeon.title() + " Surgeon" if current_category in ["Unspecified", "Unknown", None] else current_category

    # Search for other general specializations and diseases
    for specialization in specializations:
        if re.search(rf"\b{specialization.lower()}\b", name_lower) or re.search(rf"\b{specialization.lower()}\b", address_lower) or re.search(rf"\b{specialization.lower()}\b", city_lower):
            if current_category in ["Unspecified", "Unknown", None]:
                return specialization.title()

    return current_category

# Clean columns
df["Name"] = df["Name"].str.replace(r"Dr\.?\s+", "Dr ", regex=True).str.strip()
df["Category"] = df["Category"].fillna("Unspecified").replace("Unknown", "Unspecified")
df["Address/Details"] = df["Address/Details"].apply(clean_address)
df["City"] = df["City"].fillna("Unspecified").str.strip()
df["Rating"] = pd.to_numeric(df["Rating"], errors="coerce")

# Update 'Category' with specializations (only if 'Category' is 'Unspecified' or 'Unknown')
df["Category"] = df.apply(lambda row: extract_specializations(row["Name"], row["Address/Details"], row["City"], row["Category"]), axis=1)

# Final cleaned format
cleaned_df = df[["Name", "Category", "Address/Details", "City", "Rating"]]

# Save cleaned data
cleaned_df.to_csv("cleaned_doctors.csv", index=False)

print("✅ Doctors data cleaned, specializations and disease categories extracted from Name, Address, and City into 'Category' column and saved in 'cleaned_doctors_dataa.csv'")
# Out:
# ✅ Doctors data cleaned, specializations and disease categories extracted from Name, Address, and City into 'Category' column and saved in 'cleaned_doctors_dataa.csv'

# %%
# Check how many ratings are unknown (NaN)
unknown_ratings_count = df["Rating"].isna().sum()

# Print the result
print(f"Number of unknown ratings: {unknown_ratings_count}")
# Out:
# Number of unknown ratings: 0

# %%
# Impute missing ratings with the mean rating
mean_rating = df["Rating"].mean()
df["Rating"] = df["Rating"].fillna(mean_rating)

# Round the 'Rating' column to 2 decimal places
df["Rating"] = df["Rating"].round(2)

# Save the cleaned data
df.to_csv("cleaned_doctors.csv", index=False)

print("✅ Ratings rounded to 2 decimal places and data saved successfully.")
# Out:
# ✅ Ratings rounded to 2 decimal places and data saved successfully.
